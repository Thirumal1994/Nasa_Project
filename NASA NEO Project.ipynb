# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
API_KEY = "q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K"

import requests

url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&api_key={API_KEY}"

response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-08&end_date=2024-01-15&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-12-25&end_date=2024-01-01&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#  'element_count': 35,
#  'near_earth_objects': {'2024-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2415949',
#     'neo_reference_id': '2415949',
#     'name': '415949 (2001 XY10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#     'absolute_magnitude_h': 19.37,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#       'estimated_diameter_max': 0.7944013596},
#      'meters': {'estimated_diameter_min': 355.267088298,
#       'estimated_diameter_max': 794.4013596028},
#      'miles': {'estimated_diameter_min': 0.2207526659,
#       'estimated_diameter_max': 0.4936179672},
#      'feet': {'estimated_diameter_min': 1165.5744739718,
#       'estimated_diameter_max': 2606.3037566394}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 13:14',
#       'epoch_date_close_approach': 1704201240000,
#       'relative_velocity': {'kilometers_per_second': '15.8905264223',
#        'kilometers_per_hour': '57205.8951204341',
#        'miles_per_hour': '35545.5185541386'},
#       'miss_distance': {'astronomical': '0.3372535274',
#        'lunar': '131.1916221586',
#        'kilometers': '50452409.349026638',
#        'miles': '31349673.4658100844'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3160747?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3160747',
#     'neo_reference_id': '3160747',
#     'name': '(2003 SR84)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3160747',
#     'absolute_magnitude_h': 26.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#       'estimated_diameter_max': 0.0375007522},
#      'meters': {'estimated_diameter_min': 16.7708462163,
#       'estimated_diameter_max': 37.5007521798},
#      'miles': {'estimated_diameter_min': 0.0104209175,
#       'estimated_diameter_max': 0.0233018799},
#      'feet': {'estimated_diameter_min': 55.0224631002,
#       'estimated_diameter_max': 123.0339677816}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 22:45',
#       'epoch_date_close_approach': 1704235500000,
#       'relative_velocity': {'kilometers_per_second': '10.7191818981',
#        'kilometers_per_hour': '38589.054833182',
#        'miles_per_hour': '23977.7379878735'},
#       'miss_distance': {'astronomical': '0.1323425924',
#        'lunar': '51.4812684436',
#        'kilometers': '19798169.933318188',
#        'miles': '12302012.3446714744'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3309828?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3309828',
#     'neo_reference_id': '3309828',
#     'name': '(2005 YQ96)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3309828',
#     'absolute_magnitude_h': 20.62,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1997813652,
#       'estimated_diameter_max': 0.4467247133},
#      'meters': {'estimated_diameter_min': 199.78136523,
#       'estimated_diameter_max': 446.7247132921},
#      'miles': {'estimated_diameter_min': 0.1241383467,
#       'estimated_diameter_max': 0.2775817818},
#      'feet': {'estimated_diameter_min': 655.4506943013,
#       'estimated_diameter_max': 1465.6323083572}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 19:42',
#       'epoch_date_close_approach': 1704224520000,
#       'relative_velocity': {'kilometers_per_second': '15.6702817644',
#        'kilometers_per_hour': '56413.0143519451',
#        'miles_per_hour': '35052.8532788517'},
#       'miss_distance': {'astronomical': '0.1670126223',
#        'lunar': '64.9679100747',
#        'kilometers': '24984732.559194501',
#        'miles': '15524792.9180700738'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3457842?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3457842',
#     'neo_reference_id': '3457842',
#     'name': '(2009 HC21)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3457842',
#     'absolute_magnitude_h': 22.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1010543415,
#       'estimated_diameter_max': 0.2259643771},
#      'meters': {'estimated_diameter_min': 101.054341542,
#       'estimated_diameter_max': 225.9643771094},
#      'miles': {'estimated_diameter_min': 0.0627922373,
#       'estimated_diameter_max': 0.140407711},
#      'feet': {'estimated_diameter_min': 331.5431259047,
#       'estimated_diameter_max': 741.3529669956}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 12:06',
#       'epoch_date_close_approach': 1704197160000,
#       'relative_velocity': {'kilometers_per_second': '6.0808661718',
#        'kilometers_per_hour': '21891.1182185894',
#        'miles_per_hour': '13602.2895397674'},
#       'miss_distance': {'astronomical': '0.4920511029',
#        'lunar': '191.4078790281',
#        'kilometers': '73609796.924990823',
#        'miles': '45739006.8632584374'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3553062?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3553062',
#     'neo_reference_id': '3553062',
#     'name': '(2010 XA11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3553062',
#     'absolute_magnitude_h': 26.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0160160338,
#       'estimated_diameter_max': 0.0358129403},
#      'meters': {'estimated_diameter_min': 16.0160337979,
#       'estimated_diameter_max': 35.8129403019},
#      'miles': {'estimated_diameter_min': 0.0099518989,
#       'estimated_diameter_max': 0.0222531225},
#      'feet': {'estimated_diameter_min': 52.5460443254,
#       'estimated_diameter_max': 117.4965270602}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 15:31',
#       'epoch_date_close_approach': 1704209460000,
#       'relative_velocity': {'kilometers_per_second': '8.7413828775',
#        'kilometers_per_hour': '31468.9783588978',
#        'miles_per_hour': '19553.5993586163'},
#       'miss_distance': {'astronomical': '0.2358022486',
#        'lunar': '91.7270747054',
#        'kilometers': '35275514.131770482',
#        'miles': '21919188.0752253716'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3591616?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3591616',
#     'neo_reference_id': '3591616',
#     'name': '(2011 YP10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3591616',
#     'absolute_magnitude_h': 23.94,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0433066885,
#       'estimated_diameter_max': 0.0968366995},
#      'meters': {'estimated_diameter_min': 43.3066885476,
#       'estimated_diameter_max': 96.8366994728},
#      'miles': {'estimated_diameter_min': 0.0269095204,
#       'estimated_diameter_max': 0.0601715168},
#      'feet': {'estimated_diameter_min': 142.0823160544,
#       'estimated_diameter_max': 317.7057170982}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 12:59',
#       'epoch_date_close_approach': 1704200340000,
#       'relative_velocity': {'kilometers_per_second': '5.8070023218',
#        'kilometers_per_hour': '20905.2083584121',
#        'miles_per_hour': '12989.6834935922'},
#       'miss_distance': {'astronomical': '0.0704899554',
#        'lunar': '27.4205926506',
#        'kilometers': '10545147.184234998',
#        'miles': '6552450.6191110524'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3608936?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3608936',
#     'neo_reference_id': '3608936',
#     'name': '(2012 SD22)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3608936',
#     'absolute_magnitude_h': 20.05,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2597496533,
#       'estimated_diameter_max': 0.580817882},
#      'meters': {'estimated_diameter_min': 259.7496533301,
#       'estimated_diameter_max': 580.817881978},
#      'miles': {'estimated_diameter_min': 0.1614009018,
#       'estimated_diameter_max': 0.3609033881},
#      'feet': {'estimated_diameter_min': 852.1970526314,
#       'estimated_diameter_max': 1905.5705399087}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 13:50',
#       'epoch_date_close_approach': 1704203400000,
#       'relative_velocity': {'kilometers_per_second': '11.0227943004',
#        'kilometers_per_hour': '39682.059481597',
#        'miles_per_hour': '24656.8885706623'},
#       'miss_distance': {'astronomical': '0.1644228854',
#        'lunar': '63.9605024206',
#        'kilometers': '24597313.435094098',
#        'miles': '15284061.8372026324'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2613286?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2613286',
#     'neo_reference_id': '2613286',
#     'name': '613286 (2005 YQ96)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2613286',
#     'absolute_magnitude_h': 20.63,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1988634532,
#       'estimated_diameter_max': 0.4446721997},
#      'meters': {'estimated_diameter_min': 198.8634532359,
#       'estimated_diameter_max': 444.6721996757},
#      'miles': {'estimated_diameter_min': 0.1235679828,
#       'estimated_diameter_max': 0.2763064094},
#      'feet': {'estimated_diameter_min': 652.4391719144,
#       'estimated_diameter_max': 1458.8983395842}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 19:42',
#       'epoch_date_close_approach': 1704224520000,
#       'relative_velocity': {'kilometers_per_second': '15.6702896005',
#        'kilometers_per_hour': '56413.0425616862',
#        'miles_per_hour': '35052.8708072878'},
#       'miss_distance': {'astronomical': '0.16701304',
#        'lunar': '64.96807256',
#        'kilometers': '24984795.0462248',
#        'miles': '15524831.74571024'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2669051?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2669051',
#     'neo_reference_id': '2669051',
#     'name': '669051 (2012 SD22)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2669051',
#     'absolute_magnitude_h': 20.08,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2561857545,
#       'estimated_diameter_max': 0.5728487619},
#      'meters': {'estimated_diameter_min': 256.1857544793,
#       'estimated_diameter_max': 572.8487618827},
#      'miles': {'estimated_diameter_min': 0.1591863984,
#       'estimated_diameter_max': 0.355951608},
#      'feet': {'estimated_diameter_min': 840.5044707257,
#       'estimated_diameter_max': 1879.4251319352}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-02',
#       'close_approach_date_full': '2024-Jan-02 13:50',
#       'epoch_date_close_approach': 1704203400000,
#       'relative_velocity': {'kilometers_per_second': '11.0227939149',
#        'kilometers_per_hour': '39682.0580935237',
#        'miles_per_hour': '24656.8877081676'},
#       'miss_distance': {'astronomical': '0.1644228604',
#        'lunar': '63.9604926956',
#        'kilometers': '24597309.695147348',
#        'miles': '15284059.5133074824'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2450293?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2450293',
#     'neo_reference_id': '2450293',
#     'name': '450293 (2004 LV3)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2450293',
#     'absolute_magnitude_h': 18.83,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4555698523,
#       'estimated_diameter_max': 1.0186851583},
#      'meters': {'estimated_diameter_min': 455.5698523357,
#       'estimated_diameter_max': 1018.6851583223},
#      'miles': {'estimated_diameter_min': 0.2830778947,
#       'estimated_diameter_max': 0.6329814155},
#      'feet': {'estimated_diameter_min': 1494.6517943372,
#       'estimated_diameter_max': 3342.14301483}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-04',
#       'close_approach_date_full': '2024-Jan-04 13:59',
#       'epoch_date_close_approach': 1704376740000,
#       'relative_velocity': {'kilometers_per_second': '23.7178883208',
#        'kilometers_per_hour': '85384.3979548105',
#        'miles_per_hour': '53054.5443847543'},
#       'miss_distance': {'astronomical': '0.2515406075',
#        'lunar': '97.8492963175',
#        'kilometers': '37629939.100506025',
#        'miles': '23382159.911892145'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3541505?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3541505',
#     'neo_reference_id': '3541505',
#     'name': '(2010 PJ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3541505',
#     'absolute_magnitude_h': 22.14,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0992098919,
#       'estimated_diameter_max': 0.2218400624},
#      'meters': {'estimated_diameter_min': 99.2098919421,
#       'estimated_diameter_max': 221.8400624229},
#      'miles': {'estimated_diameter_min': 0.0616461498,
#       'estimated_diameter_max': 0.1378449814},
#      'feet': {'estimated_diameter_min': 325.4917818793,
#       'estimated_diameter_max': 727.8217503997}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-04',
#       'close_approach_date_full': '2024-Jan-04 13:32',
#       'epoch_date_close_approach': 1704375120000,
#       'relative_velocity': {'kilometers_per_second': '18.4122352237',
#        'kilometers_per_hour': '66284.046805343',
#        'miles_per_hour': '41186.3289719088'},
#       'miss_distance': {'astronomical': '0.325882928',
#        'lunar': '126.768458992',
#        'kilometers': '48751391.89816336',
#        'miles': '30292710.233879968'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3154493?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3154493',
#     'neo_reference_id': '3154493',
#     'name': '(2003 JV14)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3154493',
#     'absolute_magnitude_h': 21.39,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1401376972,
#       'estimated_diameter_max': 0.3133574171},
#      'meters': {'estimated_diameter_min': 140.1376971662,
#       'estimated_diameter_max': 313.3574170739},
#      'miles': {'estimated_diameter_min': 0.087077501,
#       'estimated_diameter_max': 0.1947112116},
#      'feet': {'estimated_diameter_min': 459.7693623707,
#       'estimated_diameter_max': 1028.0755482326}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 08:26',
#       'epoch_date_close_approach': 1704270360000,
#       'relative_velocity': {'kilometers_per_second': '13.6603242742',
#        'kilometers_per_hour': '49177.1673871585',
#        'miles_per_hour': '30556.7793689819'},
#       'miss_distance': {'astronomical': '0.2621610014',
#        'lunar': '101.9806295446',
#        'kilometers': '39218727.406507018',
#        'miles': '24369387.1869041284'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3440771?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3440771',
#     'neo_reference_id': '3440771',
#     'name': '(2008 WZ94)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3440771',
#     'absolute_magnitude_h': 20.26,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.235806068,
#       'estimated_diameter_max': 0.5272783976},
#      'meters': {'estimated_diameter_min': 235.8060679997,
#       'estimated_diameter_max': 527.2783975542},
#      'miles': {'estimated_diameter_min': 0.1465230523,
#       'estimated_diameter_max': 0.3276355052},
#      'feet': {'estimated_diameter_min': 773.6419801361,
#       'estimated_diameter_max': 1729.9160578319}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 08:50',
#       'epoch_date_close_approach': 1704271800000,
#       'relative_velocity': {'kilometers_per_second': '14.4225755627',
#        'kilometers_per_hour': '51921.2720256358',
#        'miles_per_hour': '32261.8592761513'},
#       'miss_distance': {'astronomical': '0.4821520704',
#        'lunar': '187.5571553856',
#        'kilometers': '72128922.747930048',
#        'miles': '44818834.3186007424'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3591759?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3591759',
#     'neo_reference_id': '3591759',
#     'name': '(2011 YE40)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3591759',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 23:21',
#       'epoch_date_close_approach': 1704324060000,
#       'relative_velocity': {'kilometers_per_second': '13.0832838643',
#        'kilometers_per_hour': '47099.8219113461',
#        'miles_per_hour': '29265.9976759695'},
#       'miss_distance': {'astronomical': '0.1185645923',
#        'lunar': '46.1216264047',
#        'kilometers': '17737010.465498401',
#        'miles': '11021267.2403078938'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595775?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3595775',
#     'neo_reference_id': '3595775',
#     'name': '(2012 AB11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3595775',
#     'absolute_magnitude_h': 22.32,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#       'estimated_diameter_max': 0.2041925905},
#      'meters': {'estimated_diameter_min': 91.3177025518,
#       'estimated_diameter_max': 204.1925904549},
#      'miles': {'estimated_diameter_min': 0.0567421722,
#       'estimated_diameter_max': 0.1268793541},
#      'feet': {'estimated_diameter_min': 299.59877124,
#       'estimated_diameter_max': 669.9232184681}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 09:58',
#       'epoch_date_close_approach': 1704275880000,
#       'relative_velocity': {'kilometers_per_second': '18.3613912555',
#        'kilometers_per_hour': '66101.0085197716',
#        'miles_per_hour': '41072.5960994103'},
#       'miss_distance': {'astronomical': '0.2870697327',
#        'lunar': '111.6701260203',
#        'kilometers': '42945020.553389349',
#        'miles': '26684798.3813330562'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3605578?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3605578',
#     'neo_reference_id': '3605578',
#     'name': '(2012 LJ2)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3605578',
#     'absolute_magnitude_h': 21.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1214940408,
#       'estimated_diameter_max': 0.2716689341},
#      'meters': {'estimated_diameter_min': 121.4940407996,
#       'estimated_diameter_max': 271.6689340891},
#      'miles': {'estimated_diameter_min': 0.0754928736,
#       'estimated_diameter_max': 0.1688071972},
#      'feet': {'estimated_diameter_min': 398.6025088171,
#       'estimated_diameter_max': 891.3023057169}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 13:43',
#       'epoch_date_close_approach': 1704289380000,
#       'relative_velocity': {'kilometers_per_second': '17.3904977402',
#        'kilometers_per_hour': '62605.7918647103',
#        'miles_per_hour': '38900.8043950473'},
#       'miss_distance': {'astronomical': '0.4856779711',
#        'lunar': '188.9287307579',
#        'kilometers': '72656389.982481557',
#        'miles': '45146587.2600452066'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3751529?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3751529',
#     'neo_reference_id': '3751529',
#     'name': '(2016 GZ215)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3751529',
#     'absolute_magnitude_h': 21.08,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1616422833,
#       'estimated_diameter_max': 0.3614431336},
#      'meters': {'estimated_diameter_min': 161.6422833399,
#       'estimated_diameter_max': 361.4431335863},
#      'miles': {'estimated_diameter_min': 0.1004398272,
#       'estimated_diameter_max': 0.2245902814},
#      'feet': {'estimated_diameter_min': 530.3224688728,
#       'estimated_diameter_max': 1185.8370903951}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 14:28',
#       'epoch_date_close_approach': 1704292080000,
#       'relative_velocity': {'kilometers_per_second': '3.7257304746',
#        'kilometers_per_hour': '13412.6297084999',
#        'miles_per_hour': '8334.0864985954'},
#       'miss_distance': {'astronomical': '0.3169592421',
#        'lunar': '123.2971451769',
#        'kilometers': '47416427.494974327',
#        'miles': '29463201.8185546326'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2668499?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2668499',
#     'neo_reference_id': '2668499',
#     'name': '668499 (2012 AB11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2668499',
#     'absolute_magnitude_h': 22.32,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#       'estimated_diameter_max': 0.2041925905},
#      'meters': {'estimated_diameter_min': 91.3177025518,
#       'estimated_diameter_max': 204.1925904549},
#      'miles': {'estimated_diameter_min': 0.0567421722,
#       'estimated_diameter_max': 0.1268793541},
#      'feet': {'estimated_diameter_min': 299.59877124,
#       'estimated_diameter_max': 669.9232184681}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 09:58',
#       'epoch_date_close_approach': 1704275880000,
#       'relative_velocity': {'kilometers_per_second': '18.3613912419',
#        'kilometers_per_hour': '66101.008470871',
#        'miles_per_hour': '41072.5960690253'},
#       'miss_distance': {'astronomical': '0.2870697328',
#        'lunar': '111.6701260592',
#        'kilometers': '42945020.568349136',
#        'miles': '26684798.3906286368'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2676480?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2676480',
#     'neo_reference_id': '2676480',
#     'name': '676480 (2016 GZ215)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2676480',
#     'absolute_magnitude_h': 21.08,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1616422833,
#       'estimated_diameter_max': 0.3614431336},
#      'meters': {'estimated_diameter_min': 161.6422833399,
#       'estimated_diameter_max': 361.4431335863},
#      'miles': {'estimated_diameter_min': 0.1004398272,
#       'estimated_diameter_max': 0.2245902814},
#      'feet': {'estimated_diameter_min': 530.3224688728,
#       'estimated_diameter_max': 1185.8370903951}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-03',
#       'close_approach_date_full': '2024-Jan-03 14:28',
#       'epoch_date_close_approach': 1704292080000,
#       'relative_velocity': {'kilometers_per_second': '3.725730427',
#        'kilometers_per_hour': '13412.6295371653',
#        'miles_per_hour': '8334.0863921347'},
#       'miss_distance': {'astronomical': '0.316959242',
#        'lunar': '123.297145138',
#        'kilometers': '47416427.48001454',
#        'miles': '29463201.809259052'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-06': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2304640?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2304640',
#     'neo_reference_id': '2304640',
#     'name': '304640 (2006 WW1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2304640',
#     'absolute_magnitude_h': 19.17,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3895426161,
#       'estimated_diameter_max': 0.8710437698},
#      'meters': {'estimated_diameter_min': 389.5426161261,
#       'estimated_diameter_max': 871.043769791},
#      'miles': {'estimated_diameter_min': 0.2420504849,
#       'estimated_diameter_max': 0.5412413383},
#      'feet': {'estimated_diameter_min': 1278.0269966911,
#       'estimated_diameter_max': 2857.7552416812}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 18:17',
#       'epoch_date_close_approach': 1704565020000,
#       'relative_velocity': {'kilometers_per_second': '23.0326073542',
#        'kilometers_per_hour': '82917.386474944',
#        'miles_per_hour': '51521.6393905006'},
#       'miss_distance': {'astronomical': '0.3042250642',
#        'lunar': '118.3435499738',
#        'kilometers': '45511421.604933254',
#        'miles': '28279486.0481127452'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3102756?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3102756',
#     'neo_reference_id': '3102756',
#     'name': '(2002 AO11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3102756',
#     'absolute_magnitude_h': 23.05,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.065246163,
#       'estimated_diameter_max': 0.1458948557},
#      'meters': {'estimated_diameter_min': 65.2461629789,
#       'estimated_diameter_max': 145.8948556919},
#      'miles': {'estimated_diameter_min': 0.0405420735,
#       'estimated_diameter_max': 0.0906548324},
#      'feet': {'estimated_diameter_min': 214.0622213477,
#       'estimated_diameter_max': 478.6576783481}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 17:20',
#       'epoch_date_close_approach': 1704561600000,
#       'relative_velocity': {'kilometers_per_second': '18.4313859429',
#        'kilometers_per_hour': '66352.9893943133',
#        'miles_per_hour': '41229.1672155943'},
#       'miss_distance': {'astronomical': '0.4011389088',
#        'lunar': '156.0430355232',
#        'kilometers': '60009526.330604256',
#        'miles': '37288190.5854644928'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3623521?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3623521',
#     'neo_reference_id': '3623521',
#     'name': '(2013 AK20)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3623521',
#     'absolute_magnitude_h': 23.19,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0611723235,
#       'estimated_diameter_max': 0.1367854737},
#      'meters': {'estimated_diameter_min': 61.1723235067,
#       'estimated_diameter_max': 136.7854737026},
#      'miles': {'estimated_diameter_min': 0.0380107078,
#       'estimated_diameter_max': 0.0849945266},
#      'feet': {'estimated_diameter_min': 200.6966058538,
#       'estimated_diameter_max': 448.7712535425}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 09:44',
#       'epoch_date_close_approach': 1704534240000,
#       'relative_velocity': {'kilometers_per_second': '9.2913935384',
#        'kilometers_per_hour': '33449.0167383958',
#        'miles_per_hour': '20783.9182061438'},
#       'miss_distance': {'astronomical': '0.2658726974',
#        'lunar': '103.4244792886',
#        'kilometers': '39773989.222194538',
#        'miles': '24714410.8802111044'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3630638?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3630638',
#     'neo_reference_id': '3630638',
#     'name': '(2013 EU9)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3630638',
#     'absolute_magnitude_h': 21.66,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1237527837,
#       'estimated_diameter_max': 0.2767196367},
#      'meters': {'estimated_diameter_min': 123.7527836584,
#       'estimated_diameter_max': 276.719636665},
#      'miles': {'estimated_diameter_min': 0.0768963909,
#       'estimated_diameter_max': 0.1719455574},
#      'feet': {'estimated_diameter_min': 406.0130827378,
#       'estimated_diameter_max': 907.872852756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 16:52',
#       'epoch_date_close_approach': 1704559920000,
#       'relative_velocity': {'kilometers_per_second': '6.4568616725',
#        'kilometers_per_hour': '23244.7020210603',
#        'miles_per_hour': '14443.3538752527'},
#       'miss_distance': {'astronomical': '0.4595500589',
#        'lunar': '178.7649729121',
#        'kilometers': '68747709.969814543',
#        'miles': '42717846.1223969734'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3794988?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3794988',
#     'neo_reference_id': '3794988',
#     'name': '(2017 YZ1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3794988',
#     'absolute_magnitude_h': 20.43,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2180494405,
#       'estimated_diameter_max': 0.4875733714},
#      'meters': {'estimated_diameter_min': 218.0494404829,
#       'estimated_diameter_max': 487.5733713755},
#      'miles': {'estimated_diameter_min': 0.1354895989,
#       'estimated_diameter_max': 0.3029639533},
#      'feet': {'estimated_diameter_min': 715.3853263138,
#       'estimated_diameter_max': 1599.6502197435}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 05:43',
#       'epoch_date_close_approach': 1704519780000,
#       'relative_velocity': {'kilometers_per_second': '12.2272943072',
#        'kilometers_per_hour': '44018.2595059564',
#        'miles_per_hour': '27351.2346357983'},
#       'miss_distance': {'astronomical': '0.4823054753',
#        'lunar': '187.6168298917',
#        'kilometers': '72151871.794217611',
#        'miles': '44833094.1947245918'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2585310?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2585310',
#     'neo_reference_id': '2585310',
#     'name': '585310 (2017 YZ1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2585310',
#     'absolute_magnitude_h': 20.41,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2200670271,
#       'estimated_diameter_max': 0.4920848322},
#      'meters': {'estimated_diameter_min': 220.0670271147,
#       'estimated_diameter_max': 492.0848322348},
#      'miles': {'estimated_diameter_min': 0.1367432687,
#       'estimated_diameter_max': 0.3057672443},
#      'feet': {'estimated_diameter_min': 722.0047052391,
#       'estimated_diameter_max': 1614.4516009894}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 05:43',
#       'epoch_date_close_approach': 1704519780000,
#       'relative_velocity': {'kilometers_per_second': '12.227293154',
#        'kilometers_per_hour': '44018.2553543482',
#        'miles_per_hour': '27351.2320561504'},
#       'miss_distance': {'astronomical': '0.4823053713',
#        'lunar': '187.6167894357',
#        'kilometers': '72151856.236039131',
#        'miles': '44833084.5273207678'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2591179?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2591179',
#     'neo_reference_id': '2591179',
#     'name': '591179 (2013 EU9)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2591179',
#     'absolute_magnitude_h': 21.66,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1237527837,
#       'estimated_diameter_max': 0.2767196367},
#      'meters': {'estimated_diameter_min': 123.7527836584,
#       'estimated_diameter_max': 276.719636665},
#      'miles': {'estimated_diameter_min': 0.0768963909,
#       'estimated_diameter_max': 0.1719455574},
#      'feet': {'estimated_diameter_min': 406.0130827378,
#       'estimated_diameter_max': 907.872852756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-06',
#       'close_approach_date_full': '2024-Jan-06 16:52',
#       'epoch_date_close_approach': 1704559920000,
#       'relative_velocity': {'kilometers_per_second': '6.4568624469',
#        'kilometers_per_hour': '23244.7048088382',
#        'miles_per_hour': '14443.3556074695'},
#       'miss_distance': {'astronomical': '0.4595501104',
#        'lunar': '178.7649929456',
#        'kilometers': '68747717.674104848',
#        'miles': '42717850.9096209824'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-05': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3387092?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3387092',
#     'neo_reference_id': '3387092',
#     'name': '(2007 SG11)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3387092',
#     'absolute_magnitude_h': 22.68,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.077366861,
#       'estimated_diameter_max': 0.1729975604},
#      'meters': {'estimated_diameter_min': 77.3668609982,
#       'estimated_diameter_max': 172.9975603978},
#      'miles': {'estimated_diameter_min': 0.0480735238,
#       'estimated_diameter_max': 0.1074956671},
#      'feet': {'estimated_diameter_min': 253.8282922374,
#       'estimated_diameter_max': 567.5773160554}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-05',
#       'close_approach_date_full': '2024-Jan-05 21:10',
#       'epoch_date_close_approach': 1704489000000,
#       'relative_velocity': {'kilometers_per_second': '5.8695959378',
#        'kilometers_per_hour': '21130.5453762448',
#        'miles_per_hour': '13129.6991533672'},
#       'miss_distance': {'astronomical': '0.279217138',
#        'lunar': '108.615466682',
#        'kilometers': '41770289.11229606',
#        'miles': '25954854.111803228'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-08': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2168318?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2168318',
#     'neo_reference_id': '2168318',
#     'name': '168318 (1989 DA)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2168318',
#     'absolute_magnitude_h': 18.91,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.439091446,
#       'estimated_diameter_max': 0.9818383215},
#      'meters': {'estimated_diameter_min': 439.0914459693,
#       'estimated_diameter_max': 981.838321526},
#      'miles': {'estimated_diameter_min': 0.2728386909,
#       'estimated_diameter_max': 0.6100858597},
#      'feet': {'estimated_diameter_min': 1440.5887795938,
#       'estimated_diameter_max': 3221.2544387953}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-08',
#       'close_approach_date_full': '2024-Jan-08 04:17',
#       'epoch_date_close_approach': 1704687420000,
#       'relative_velocity': {'kilometers_per_second': '8.8851478203',
#        'kilometers_per_hour': '31986.5321530766',
#        'miles_per_hour': '19875.1871592269'},
#       'miss_distance': {'astronomical': '0.1176981136',
#        'lunar': '45.7845661904',
#        'kilometers': '17607387.097578032',
#        'miles': '10940723.0143675616'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3102728?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3102728',
#     'neo_reference_id': '3102728',
#     'name': '(2002 AY1)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3102728',
#     'absolute_magnitude_h': 20.85,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1797028549,
#       'estimated_diameter_max': 0.4018277992},
#      'meters': {'estimated_diameter_min': 179.7028548592,
#       'estimated_diameter_max': 401.8277992159},
#      'miles': {'estimated_diameter_min': 0.1116621426,
#       'estimated_diameter_max': 0.2496841414},
#      'feet': {'estimated_diameter_min': 589.5763143362,
#       'estimated_diameter_max': 1318.3327167796}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-08',
#       'close_approach_date_full': '2024-Jan-08 18:11',
#       'epoch_date_close_approach': 1704737460000,
#       'relative_velocity': {'kilometers_per_second': '17.3391696439',
#        'kilometers_per_hour': '62421.0107180472',
#        'miles_per_hour': '38785.9885764444'},
#       'miss_distance': {'astronomical': '0.0387907687',
#        'lunar': '15.0896090243',
#        'kilometers': '5803016.373182669',
#        'miles': '3605827.1698680722'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3599868?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3599868',
#     'neo_reference_id': '3599868',
#     'name': '(2012 DN31)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3599868',
#     'absolute_magnitude_h': 24.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0421264611,
#       'estimated_diameter_max': 0.0941976306},
#      'meters': {'estimated_diameter_min': 42.1264610556,
#       'estimated_diameter_max': 94.1976305719},
#      'miles': {'estimated_diameter_min': 0.0261761612,
#       'estimated_diameter_max': 0.0585316759},
#      'feet': {'estimated_diameter_min': 138.2101784897,
#       'estimated_diameter_max': 309.0473542854}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-08',
#       'close_approach_date_full': '2024-Jan-08 02:10',
#       'epoch_date_close_approach': 1704679800000,
#       'relative_velocity': {'kilometers_per_second': '20.2701167347',
#        'kilometers_per_hour': '72972.4202450971',
#        'miles_per_hour': '45342.2241239605'},
#       'miss_distance': {'astronomical': '0.438299464',
#        'lunar': '170.498491496',
#        'kilometers': '65568666.23654168',
#        'miles': '40742479.945487984'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2024-01-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2199003?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2199003',
#     'neo_reference_id': '2199003',
#     'name': '199003 (2005 WJ56)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2199003',
#     'absolute_magnitude_h': 18.16,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.620233153,
#       'estimated_diameter_max': 1.3868834919},
#      'meters': {'estimated_diameter_min': 620.2331529543,
#       'estimated_diameter_max': 1386.8834919048},
#      'miles': {'estimated_diameter_min': 0.3853948945,
#       'estimated_diameter_max': 0.8617691822},
#      'feet': {'estimated_diameter_min': 2034.8857375386,
#       'estimated_diameter_max': 4550.142835581}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 02:32',
#       'epoch_date_close_approach': 1704594720000,
#       'relative_velocity': {'kilometers_per_second': '15.2908365812',
#        'kilometers_per_hour': '55047.0116924064',
#        'miles_per_hour': '34204.07234854'},
#       'miss_distance': {'astronomical': '0.1995345465',
#        'lunar': '77.6189385885',
#        'kilometers': '29849943.147815955',
#        'miles': '18547894.594751979'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2434188?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '2434188',
#     'neo_reference_id': '2434188',
#     'name': '434188 (2003 AD23)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2434188',
#     'absolute_magnitude_h': 19.09,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4041615334,
#       'estimated_diameter_max': 0.9037326626},
#      'meters': {'estimated_diameter_min': 404.1615334029,
#       'estimated_diameter_max': 903.7326625794},
#      'miles': {'estimated_diameter_min': 0.2511342562,
#       'estimated_diameter_max': 0.5615532683},
#      'feet': {'estimated_diameter_min': 1325.9893252496,
#       'estimated_diameter_max': 2965.0022686971}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 07:28',
#       'epoch_date_close_approach': 1704612480000,
#       'relative_velocity': {'kilometers_per_second': '33.8373421713',
#        'kilometers_per_hour': '121814.4318166937',
#        'miles_per_hour': '75690.7507029895'},
#       'miss_distance': {'astronomical': '0.204313989',
#        'lunar': '79.478141721',
#        'kilometers': '30564937.56560343',
#        'miles': '18992171.524570134'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3398095?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3398095',
#     'neo_reference_id': '3398095',
#     'name': '(2007 YZ)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3398095',
#     'absolute_magnitude_h': 19.53,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3300311834,
#       'estimated_diameter_max': 0.7379721607},
#      'meters': {'estimated_diameter_min': 330.0311833581,
#       'estimated_diameter_max': 737.9721606833},
#      'miles': {'estimated_diameter_min': 0.2050718064,
#       'estimated_diameter_max': 0.4585544995},
#      'feet': {'estimated_diameter_min': 1082.7795076085,
#       'estimated_diameter_max': 2421.1685836563}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 00:39',
#       'epoch_date_close_approach': 1704587940000,
#       'relative_velocity': {'kilometers_per_second': '17.5905759528',
#        'kilometers_per_hour': '63326.0734302496',
#        'miles_per_hour': '39348.3593489237'},
#       'miss_distance': {'astronomical': '0.1917667009',
#        'lunar': '74.5972466501',
#        'kilometers': '28687889.991567083',
#        'miles': '17825828.2461204254'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3520662?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3520662',
#     'neo_reference_id': '3520662',
#     'name': '(2010 JR34)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3520662',
#     'absolute_magnitude_h': 27.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#       'estimated_diameter_max': 0.0171411509},
#      'meters': {'estimated_diameter_min': 7.6657557353,
#       'estimated_diameter_max': 17.1411509231},
#      'miles': {'estimated_diameter_min': 0.0047632783,
#       'estimated_diameter_max': 0.0106510141},
#      'feet': {'estimated_diameter_min': 25.1501180466,
#       'estimated_diameter_max': 56.2373735944}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 11:45',
#       'epoch_date_close_approach': 1704627900000,
#       'relative_velocity': {'kilometers_per_second': '10.5972841382',
#        'kilometers_per_hour': '38150.2228974764',
#        'miles_per_hour': '23705.0648887125'},
#       'miss_distance': {'astronomical': '0.203565311',
#        'lunar': '79.186905979',
#        'kilometers': '30452936.93148757',
#        'miles': '18922577.557645666'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3596030?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#     'id': '3596030',
#     'neo_reference_id': '3596030',
#     'name': '(2012 BV13)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3596030',
#     'absolute_magnitude_h': 22.29,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0925880583,
#       'estimated_diameter_max': 0.2070331923},
#      'meters': {'estimated_diameter_min': 92.5880583366,
#       'estimated_diameter_max': 207.0331923453},
#      'miles': {'estimated_diameter_min': 0.0575315344,
#       'estimated_diameter_max': 0.1286444218},
#      'feet': {'estimated_diameter_min': 303.766605313,
#       'estimated_diameter_max': 679.2427787741}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2024-01-07',
#       'close_approach_date_full': '2024-Jan-07 09:14',
#       'epoch_date_close_approach': 1704618840000,
#       'relative_velocity': {'kilometers_per_second': '18.7982461783',
#        'kilometers_per_hour': '67673.6862419358',
#        'miles_per_hour': '42049.7968762739'},
#       'miss_distance': {'astronomical': '0.476653263',
#        'lunar': '185.418119307',
#        'kilometers': '71306312.87334981',
#        'miles': '44307688.244694978'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
data.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %%
data['links']
# Out:
# {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-08&end_date=2024-01-15&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K',
#  'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-12-25&end_date=2024-01-01&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K',
#  'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-08&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'}

# %%
data['element_count']
# Out:
# 35

# %%
data['near_earth_objects']
# Out:
# {'2024-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2415949',
#    'neo_reference_id': '2415949',
#    'name': '415949 (2001 XY10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#    'absolute_magnitude_h': 19.37,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#      'estimated_diameter_max': 0.7944013596},
#     'meters': {'estimated_diameter_min': 355.267088298,
#      'estimated_diameter_max': 794.4013596028},
#     'miles': {'estimated_diameter_min': 0.2207526659,
#      'estimated_diameter_max': 0.4936179672},
#     'feet': {'estimated_diameter_min': 1165.5744739718,
#      'estimated_diameter_max': 2606.3037566394}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 13:14',
#      'epoch_date_close_approach': 1704201240000,
#      'relative_velocity': {'kilometers_per_second': '15.8905264223',
#       'kilometers_per_hour': '57205.8951204341',
#       'miles_per_hour': '35545.5185541386'},
#      'miss_distance': {'astronomical': '0.3372535274',
#       'lunar': '131.1916221586',
#       'kilometers': '50452409.349026638',
#       'miles': '31349673.4658100844'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3160747?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3160747',
#    'neo_reference_id': '3160747',
#    'name': '(2003 SR84)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3160747',
#    'absolute_magnitude_h': 26.0,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#      'estimated_diameter_max': 0.0375007522},
#     'meters': {'estimated_diameter_min': 16.7708462163,
#      'estimated_diameter_max': 37.5007521798},
#     'miles': {'estimated_diameter_min': 0.0104209175,
#      'estimated_diameter_max': 0.0233018799},
#     'feet': {'estimated_diameter_min': 55.0224631002,
#      'estimated_diameter_max': 123.0339677816}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 22:45',
#      'epoch_date_close_approach': 1704235500000,
#      'relative_velocity': {'kilometers_per_second': '10.7191818981',
#       'kilometers_per_hour': '38589.054833182',
#       'miles_per_hour': '23977.7379878735'},
#      'miss_distance': {'astronomical': '0.1323425924',
#       'lunar': '51.4812684436',
#       'kilometers': '19798169.933318188',
#       'miles': '12302012.3446714744'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3309828?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3309828',
#    'neo_reference_id': '3309828',
#    'name': '(2005 YQ96)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3309828',
#    'absolute_magnitude_h': 20.62,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1997813652,
#      'estimated_diameter_max': 0.4467247133},
#     'meters': {'estimated_diameter_min': 199.78136523,
#      'estimated_diameter_max': 446.7247132921},
#     'miles': {'estimated_diameter_min': 0.1241383467,
#      'estimated_diameter_max': 0.2775817818},
#     'feet': {'estimated_diameter_min': 655.4506943013,
#      'estimated_diameter_max': 1465.6323083572}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 19:42',
#      'epoch_date_close_approach': 1704224520000,
#      'relative_velocity': {'kilometers_per_second': '15.6702817644',
#       'kilometers_per_hour': '56413.0143519451',
#       'miles_per_hour': '35052.8532788517'},
#      'miss_distance': {'astronomical': '0.1670126223',
#       'lunar': '64.9679100747',
#       'kilometers': '24984732.559194501',
#       'miles': '15524792.9180700738'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3457842?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3457842',
#    'neo_reference_id': '3457842',
#    'name': '(2009 HC21)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3457842',
#    'absolute_magnitude_h': 22.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1010543415,
#      'estimated_diameter_max': 0.2259643771},
#     'meters': {'estimated_diameter_min': 101.054341542,
#      'estimated_diameter_max': 225.9643771094},
#     'miles': {'estimated_diameter_min': 0.0627922373,
#      'estimated_diameter_max': 0.140407711},
#     'feet': {'estimated_diameter_min': 331.5431259047,
#      'estimated_diameter_max': 741.3529669956}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 12:06',
#      'epoch_date_close_approach': 1704197160000,
#      'relative_velocity': {'kilometers_per_second': '6.0808661718',
#       'kilometers_per_hour': '21891.1182185894',
#       'miles_per_hour': '13602.2895397674'},
#      'miss_distance': {'astronomical': '0.4920511029',
#       'lunar': '191.4078790281',
#       'kilometers': '73609796.924990823',
#       'miles': '45739006.8632584374'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3553062?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3553062',
#    'neo_reference_id': '3553062',
#    'name': '(2010 XA11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3553062',
#    'absolute_magnitude_h': 26.1,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0160160338,
#      'estimated_diameter_max': 0.0358129403},
#     'meters': {'estimated_diameter_min': 16.0160337979,
#      'estimated_diameter_max': 35.8129403019},
#     'miles': {'estimated_diameter_min': 0.0099518989,
#      'estimated_diameter_max': 0.0222531225},
#     'feet': {'estimated_diameter_min': 52.5460443254,
#      'estimated_diameter_max': 117.4965270602}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 15:31',
#      'epoch_date_close_approach': 1704209460000,
#      'relative_velocity': {'kilometers_per_second': '8.7413828775',
#       'kilometers_per_hour': '31468.9783588978',
#       'miles_per_hour': '19553.5993586163'},
#      'miss_distance': {'astronomical': '0.2358022486',
#       'lunar': '91.7270747054',
#       'kilometers': '35275514.131770482',
#       'miles': '21919188.0752253716'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3591616?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3591616',
#    'neo_reference_id': '3591616',
#    'name': '(2011 YP10)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3591616',
#    'absolute_magnitude_h': 23.94,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0433066885,
#      'estimated_diameter_max': 0.0968366995},
#     'meters': {'estimated_diameter_min': 43.3066885476,
#      'estimated_diameter_max': 96.8366994728},
#     'miles': {'estimated_diameter_min': 0.0269095204,
#      'estimated_diameter_max': 0.0601715168},
#     'feet': {'estimated_diameter_min': 142.0823160544,
#      'estimated_diameter_max': 317.7057170982}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 12:59',
#      'epoch_date_close_approach': 1704200340000,
#      'relative_velocity': {'kilometers_per_second': '5.8070023218',
#       'kilometers_per_hour': '20905.2083584121',
#       'miles_per_hour': '12989.6834935922'},
#      'miss_distance': {'astronomical': '0.0704899554',
#       'lunar': '27.4205926506',
#       'kilometers': '10545147.184234998',
#       'miles': '6552450.6191110524'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3608936?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3608936',
#    'neo_reference_id': '3608936',
#    'name': '(2012 SD22)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3608936',
#    'absolute_magnitude_h': 20.05,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2597496533,
#      'estimated_diameter_max': 0.580817882},
#     'meters': {'estimated_diameter_min': 259.7496533301,
#      'estimated_diameter_max': 580.817881978},
#     'miles': {'estimated_diameter_min': 0.1614009018,
#      'estimated_diameter_max': 0.3609033881},
#     'feet': {'estimated_diameter_min': 852.1970526314,
#      'estimated_diameter_max': 1905.5705399087}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 13:50',
#      'epoch_date_close_approach': 1704203400000,
#      'relative_velocity': {'kilometers_per_second': '11.0227943004',
#       'kilometers_per_hour': '39682.059481597',
#       'miles_per_hour': '24656.8885706623'},
#      'miss_distance': {'astronomical': '0.1644228854',
#       'lunar': '63.9605024206',
#       'kilometers': '24597313.435094098',
#       'miles': '15284061.8372026324'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2613286?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2613286',
#    'neo_reference_id': '2613286',
#    'name': '613286 (2005 YQ96)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2613286',
#    'absolute_magnitude_h': 20.63,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1988634532,
#      'estimated_diameter_max': 0.4446721997},
#     'meters': {'estimated_diameter_min': 198.8634532359,
#      'estimated_diameter_max': 444.6721996757},
#     'miles': {'estimated_diameter_min': 0.1235679828,
#      'estimated_diameter_max': 0.2763064094},
#     'feet': {'estimated_diameter_min': 652.4391719144,
#      'estimated_diameter_max': 1458.8983395842}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 19:42',
#      'epoch_date_close_approach': 1704224520000,
#      'relative_velocity': {'kilometers_per_second': '15.6702896005',
#       'kilometers_per_hour': '56413.0425616862',
#       'miles_per_hour': '35052.8708072878'},
#      'miss_distance': {'astronomical': '0.16701304',
#       'lunar': '64.96807256',
#       'kilometers': '24984795.0462248',
#       'miles': '15524831.74571024'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2669051?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2669051',
#    'neo_reference_id': '2669051',
#    'name': '669051 (2012 SD22)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2669051',
#    'absolute_magnitude_h': 20.08,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2561857545,
#      'estimated_diameter_max': 0.5728487619},
#     'meters': {'estimated_diameter_min': 256.1857544793,
#      'estimated_diameter_max': 572.8487618827},
#     'miles': {'estimated_diameter_min': 0.1591863984,
#      'estimated_diameter_max': 0.355951608},
#     'feet': {'estimated_diameter_min': 840.5044707257,
#      'estimated_diameter_max': 1879.4251319352}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-02',
#      'close_approach_date_full': '2024-Jan-02 13:50',
#      'epoch_date_close_approach': 1704203400000,
#      'relative_velocity': {'kilometers_per_second': '11.0227939149',
#       'kilometers_per_hour': '39682.0580935237',
#       'miles_per_hour': '24656.8877081676'},
#      'miss_distance': {'astronomical': '0.1644228604',
#       'lunar': '63.9604926956',
#       'kilometers': '24597309.695147348',
#       'miles': '15284059.5133074824'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-01-04': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2450293?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2450293',
#    'neo_reference_id': '2450293',
#    'name': '450293 (2004 LV3)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2450293',
#    'absolute_magnitude_h': 18.83,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4555698523,
#      'estimated_diameter_max': 1.0186851583},
#     'meters': {'estimated_diameter_min': 455.5698523357,
#      'estimated_diameter_max': 1018.6851583223},
#     'miles': {'estimated_diameter_min': 0.2830778947,
#      'estimated_diameter_max': 0.6329814155},
#     'feet': {'estimated_diameter_min': 1494.6517943372,
#      'estimated_diameter_max': 3342.14301483}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-04',
#      'close_approach_date_full': '2024-Jan-04 13:59',
#      'epoch_date_close_approach': 1704376740000,
#      'relative_velocity': {'kilometers_per_second': '23.7178883208',
#       'kilometers_per_hour': '85384.3979548105',
#       'miles_per_hour': '53054.5443847543'},
#      'miss_distance': {'astronomical': '0.2515406075',
#       'lunar': '97.8492963175',
#       'kilometers': '37629939.100506025',
#       'miles': '23382159.911892145'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3541505?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3541505',
#    'neo_reference_id': '3541505',
#    'name': '(2010 PJ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3541505',
#    'absolute_magnitude_h': 22.14,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0992098919,
#      'estimated_diameter_max': 0.2218400624},
#     'meters': {'estimated_diameter_min': 99.2098919421,
#      'estimated_diameter_max': 221.8400624229},
#     'miles': {'estimated_diameter_min': 0.0616461498,
#      'estimated_diameter_max': 0.1378449814},
#     'feet': {'estimated_diameter_min': 325.4917818793,
#      'estimated_diameter_max': 727.8217503997}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-04',
#      'close_approach_date_full': '2024-Jan-04 13:32',
#      'epoch_date_close_approach': 1704375120000,
#      'relative_velocity': {'kilometers_per_second': '18.4122352237',
#       'kilometers_per_hour': '66284.046805343',
#       'miles_per_hour': '41186.3289719088'},
#      'miss_distance': {'astronomical': '0.325882928',
#       'lunar': '126.768458992',
#       'kilometers': '48751391.89816336',
#       'miles': '30292710.233879968'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-01-03': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3154493?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3154493',
#    'neo_reference_id': '3154493',
#    'name': '(2003 JV14)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3154493',
#    'absolute_magnitude_h': 21.39,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1401376972,
#      'estimated_diameter_max': 0.3133574171},
#     'meters': {'estimated_diameter_min': 140.1376971662,
#      'estimated_diameter_max': 313.3574170739},
#     'miles': {'estimated_diameter_min': 0.087077501,
#      'estimated_diameter_max': 0.1947112116},
#     'feet': {'estimated_diameter_min': 459.7693623707,
#      'estimated_diameter_max': 1028.0755482326}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 08:26',
#      'epoch_date_close_approach': 1704270360000,
#      'relative_velocity': {'kilometers_per_second': '13.6603242742',
#       'kilometers_per_hour': '49177.1673871585',
#       'miles_per_hour': '30556.7793689819'},
#      'miss_distance': {'astronomical': '0.2621610014',
#       'lunar': '101.9806295446',
#       'kilometers': '39218727.406507018',
#       'miles': '24369387.1869041284'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3440771?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3440771',
#    'neo_reference_id': '3440771',
#    'name': '(2008 WZ94)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3440771',
#    'absolute_magnitude_h': 20.26,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.235806068,
#      'estimated_diameter_max': 0.5272783976},
#     'meters': {'estimated_diameter_min': 235.8060679997,
#      'estimated_diameter_max': 527.2783975542},
#     'miles': {'estimated_diameter_min': 0.1465230523,
#      'estimated_diameter_max': 0.3276355052},
#     'feet': {'estimated_diameter_min': 773.6419801361,
#      'estimated_diameter_max': 1729.9160578319}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 08:50',
#      'epoch_date_close_approach': 1704271800000,
#      'relative_velocity': {'kilometers_per_second': '14.4225755627',
#       'kilometers_per_hour': '51921.2720256358',
#       'miles_per_hour': '32261.8592761513'},
#      'miss_distance': {'astronomical': '0.4821520704',
#       'lunar': '187.5571553856',
#       'kilometers': '72128922.747930048',
#       'miles': '44818834.3186007424'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3591759?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3591759',
#    'neo_reference_id': '3591759',
#    'name': '(2011 YE40)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3591759',
#    'absolute_magnitude_h': 25.2,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#      'estimated_diameter_max': 0.0542050786},
#     'meters': {'estimated_diameter_min': 24.2412481101,
#      'estimated_diameter_max': 54.2050786336},
#     'miles': {'estimated_diameter_min': 0.0150628086,
#      'estimated_diameter_max': 0.0336814639},
#     'feet': {'estimated_diameter_min': 79.5316564495,
#      'estimated_diameter_max': 177.8381901842}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 23:21',
#      'epoch_date_close_approach': 1704324060000,
#      'relative_velocity': {'kilometers_per_second': '13.0832838643',
#       'kilometers_per_hour': '47099.8219113461',
#       'miles_per_hour': '29265.9976759695'},
#      'miss_distance': {'astronomical': '0.1185645923',
#       'lunar': '46.1216264047',
#       'kilometers': '17737010.465498401',
#       'miles': '11021267.2403078938'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595775?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3595775',
#    'neo_reference_id': '3595775',
#    'name': '(2012 AB11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3595775',
#    'absolute_magnitude_h': 22.32,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#      'estimated_diameter_max': 0.2041925905},
#     'meters': {'estimated_diameter_min': 91.3177025518,
#      'estimated_diameter_max': 204.1925904549},
#     'miles': {'estimated_diameter_min': 0.0567421722,
#      'estimated_diameter_max': 0.1268793541},
#     'feet': {'estimated_diameter_min': 299.59877124,
#      'estimated_diameter_max': 669.9232184681}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 09:58',
#      'epoch_date_close_approach': 1704275880000,
#      'relative_velocity': {'kilometers_per_second': '18.3613912555',
#       'kilometers_per_hour': '66101.0085197716',
#       'miles_per_hour': '41072.5960994103'},
#      'miss_distance': {'astronomical': '0.2870697327',
#       'lunar': '111.6701260203',
#       'kilometers': '42945020.553389349',
#       'miles': '26684798.3813330562'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3605578?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3605578',
#    'neo_reference_id': '3605578',
#    'name': '(2012 LJ2)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3605578',
#    'absolute_magnitude_h': 21.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1214940408,
#      'estimated_diameter_max': 0.2716689341},
#     'meters': {'estimated_diameter_min': 121.4940407996,
#      'estimated_diameter_max': 271.6689340891},
#     'miles': {'estimated_diameter_min': 0.0754928736,
#      'estimated_diameter_max': 0.1688071972},
#     'feet': {'estimated_diameter_min': 398.6025088171,
#      'estimated_diameter_max': 891.3023057169}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 13:43',
#      'epoch_date_close_approach': 1704289380000,
#      'relative_velocity': {'kilometers_per_second': '17.3904977402',
#       'kilometers_per_hour': '62605.7918647103',
#       'miles_per_hour': '38900.8043950473'},
#      'miss_distance': {'astronomical': '0.4856779711',
#       'lunar': '188.9287307579',
#       'kilometers': '72656389.982481557',
#       'miles': '45146587.2600452066'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3751529?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3751529',
#    'neo_reference_id': '3751529',
#    'name': '(2016 GZ215)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3751529',
#    'absolute_magnitude_h': 21.08,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1616422833,
#      'estimated_diameter_max': 0.3614431336},
#     'meters': {'estimated_diameter_min': 161.6422833399,
#      'estimated_diameter_max': 361.4431335863},
#     'miles': {'estimated_diameter_min': 0.1004398272,
#      'estimated_diameter_max': 0.2245902814},
#     'feet': {'estimated_diameter_min': 530.3224688728,
#      'estimated_diameter_max': 1185.8370903951}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 14:28',
#      'epoch_date_close_approach': 1704292080000,
#      'relative_velocity': {'kilometers_per_second': '3.7257304746',
#       'kilometers_per_hour': '13412.6297084999',
#       'miles_per_hour': '8334.0864985954'},
#      'miss_distance': {'astronomical': '0.3169592421',
#       'lunar': '123.2971451769',
#       'kilometers': '47416427.494974327',
#       'miles': '29463201.8185546326'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2668499?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2668499',
#    'neo_reference_id': '2668499',
#    'name': '668499 (2012 AB11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2668499',
#    'absolute_magnitude_h': 22.32,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#      'estimated_diameter_max': 0.2041925905},
#     'meters': {'estimated_diameter_min': 91.3177025518,
#      'estimated_diameter_max': 204.1925904549},
#     'miles': {'estimated_diameter_min': 0.0567421722,
#      'estimated_diameter_max': 0.1268793541},
#     'feet': {'estimated_diameter_min': 299.59877124,
#      'estimated_diameter_max': 669.9232184681}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 09:58',
#      'epoch_date_close_approach': 1704275880000,
#      'relative_velocity': {'kilometers_per_second': '18.3613912419',
#       'kilometers_per_hour': '66101.008470871',
#       'miles_per_hour': '41072.5960690253'},
#      'miss_distance': {'astronomical': '0.2870697328',
#       'lunar': '111.6701260592',
#       'kilometers': '42945020.568349136',
#       'miles': '26684798.3906286368'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2676480?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2676480',
#    'neo_reference_id': '2676480',
#    'name': '676480 (2016 GZ215)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2676480',
#    'absolute_magnitude_h': 21.08,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1616422833,
#      'estimated_diameter_max': 0.3614431336},
#     'meters': {'estimated_diameter_min': 161.6422833399,
#      'estimated_diameter_max': 361.4431335863},
#     'miles': {'estimated_diameter_min': 0.1004398272,
#      'estimated_diameter_max': 0.2245902814},
#     'feet': {'estimated_diameter_min': 530.3224688728,
#      'estimated_diameter_max': 1185.8370903951}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-03',
#      'close_approach_date_full': '2024-Jan-03 14:28',
#      'epoch_date_close_approach': 1704292080000,
#      'relative_velocity': {'kilometers_per_second': '3.725730427',
#       'kilometers_per_hour': '13412.6295371653',
#       'miles_per_hour': '8334.0863921347'},
#      'miss_distance': {'astronomical': '0.316959242',
#       'lunar': '123.297145138',
#       'kilometers': '47416427.48001454',
#       'miles': '29463201.809259052'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-01-06': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2304640?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2304640',
#    'neo_reference_id': '2304640',
#    'name': '304640 (2006 WW1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2304640',
#    'absolute_magnitude_h': 19.17,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3895426161,
#      'estimated_diameter_max': 0.8710437698},
#     'meters': {'estimated_diameter_min': 389.5426161261,
#      'estimated_diameter_max': 871.043769791},
#     'miles': {'estimated_diameter_min': 0.2420504849,
#      'estimated_diameter_max': 0.5412413383},
#     'feet': {'estimated_diameter_min': 1278.0269966911,
#      'estimated_diameter_max': 2857.7552416812}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 18:17',
#      'epoch_date_close_approach': 1704565020000,
#      'relative_velocity': {'kilometers_per_second': '23.0326073542',
#       'kilometers_per_hour': '82917.386474944',
#       'miles_per_hour': '51521.6393905006'},
#      'miss_distance': {'astronomical': '0.3042250642',
#       'lunar': '118.3435499738',
#       'kilometers': '45511421.604933254',
#       'miles': '28279486.0481127452'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3102756?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3102756',
#    'neo_reference_id': '3102756',
#    'name': '(2002 AO11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3102756',
#    'absolute_magnitude_h': 23.05,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.065246163,
#      'estimated_diameter_max': 0.1458948557},
#     'meters': {'estimated_diameter_min': 65.2461629789,
#      'estimated_diameter_max': 145.8948556919},
#     'miles': {'estimated_diameter_min': 0.0405420735,
#      'estimated_diameter_max': 0.0906548324},
#     'feet': {'estimated_diameter_min': 214.0622213477,
#      'estimated_diameter_max': 478.6576783481}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 17:20',
#      'epoch_date_close_approach': 1704561600000,
#      'relative_velocity': {'kilometers_per_second': '18.4313859429',
#       'kilometers_per_hour': '66352.9893943133',
#       'miles_per_hour': '41229.1672155943'},
#      'miss_distance': {'astronomical': '0.4011389088',
#       'lunar': '156.0430355232',
#       'kilometers': '60009526.330604256',
#       'miles': '37288190.5854644928'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3623521?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3623521',
#    'neo_reference_id': '3623521',
#    'name': '(2013 AK20)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3623521',
#    'absolute_magnitude_h': 23.19,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0611723235,
#      'estimated_diameter_max': 0.1367854737},
#     'meters': {'estimated_diameter_min': 61.1723235067,
#      'estimated_diameter_max': 136.7854737026},
#     'miles': {'estimated_diameter_min': 0.0380107078,
#      'estimated_diameter_max': 0.0849945266},
#     'feet': {'estimated_diameter_min': 200.6966058538,
#      'estimated_diameter_max': 448.7712535425}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 09:44',
#      'epoch_date_close_approach': 1704534240000,
#      'relative_velocity': {'kilometers_per_second': '9.2913935384',
#       'kilometers_per_hour': '33449.0167383958',
#       'miles_per_hour': '20783.9182061438'},
#      'miss_distance': {'astronomical': '0.2658726974',
#       'lunar': '103.4244792886',
#       'kilometers': '39773989.222194538',
#       'miles': '24714410.8802111044'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3630638?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3630638',
#    'neo_reference_id': '3630638',
#    'name': '(2013 EU9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3630638',
#    'absolute_magnitude_h': 21.66,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1237527837,
#      'estimated_diameter_max': 0.2767196367},
#     'meters': {'estimated_diameter_min': 123.7527836584,
#      'estimated_diameter_max': 276.719636665},
#     'miles': {'estimated_diameter_min': 0.0768963909,
#      'estimated_diameter_max': 0.1719455574},
#     'feet': {'estimated_diameter_min': 406.0130827378,
#      'estimated_diameter_max': 907.872852756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 16:52',
#      'epoch_date_close_approach': 1704559920000,
#      'relative_velocity': {'kilometers_per_second': '6.4568616725',
#       'kilometers_per_hour': '23244.7020210603',
#       'miles_per_hour': '14443.3538752527'},
#      'miss_distance': {'astronomical': '0.4595500589',
#       'lunar': '178.7649729121',
#       'kilometers': '68747709.969814543',
#       'miles': '42717846.1223969734'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3794988?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3794988',
#    'neo_reference_id': '3794988',
#    'name': '(2017 YZ1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3794988',
#    'absolute_magnitude_h': 20.43,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2180494405,
#      'estimated_diameter_max': 0.4875733714},
#     'meters': {'estimated_diameter_min': 218.0494404829,
#      'estimated_diameter_max': 487.5733713755},
#     'miles': {'estimated_diameter_min': 0.1354895989,
#      'estimated_diameter_max': 0.3029639533},
#     'feet': {'estimated_diameter_min': 715.3853263138,
#      'estimated_diameter_max': 1599.6502197435}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 05:43',
#      'epoch_date_close_approach': 1704519780000,
#      'relative_velocity': {'kilometers_per_second': '12.2272943072',
#       'kilometers_per_hour': '44018.2595059564',
#       'miles_per_hour': '27351.2346357983'},
#      'miss_distance': {'astronomical': '0.4823054753',
#       'lunar': '187.6168298917',
#       'kilometers': '72151871.794217611',
#       'miles': '44833094.1947245918'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2585310?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2585310',
#    'neo_reference_id': '2585310',
#    'name': '585310 (2017 YZ1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2585310',
#    'absolute_magnitude_h': 20.41,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2200670271,
#      'estimated_diameter_max': 0.4920848322},
#     'meters': {'estimated_diameter_min': 220.0670271147,
#      'estimated_diameter_max': 492.0848322348},
#     'miles': {'estimated_diameter_min': 0.1367432687,
#      'estimated_diameter_max': 0.3057672443},
#     'feet': {'estimated_diameter_min': 722.0047052391,
#      'estimated_diameter_max': 1614.4516009894}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 05:43',
#      'epoch_date_close_approach': 1704519780000,
#      'relative_velocity': {'kilometers_per_second': '12.227293154',
#       'kilometers_per_hour': '44018.2553543482',
#       'miles_per_hour': '27351.2320561504'},
#      'miss_distance': {'astronomical': '0.4823053713',
#       'lunar': '187.6167894357',
#       'kilometers': '72151856.236039131',
#       'miles': '44833084.5273207678'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2591179?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2591179',
#    'neo_reference_id': '2591179',
#    'name': '591179 (2013 EU9)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2591179',
#    'absolute_magnitude_h': 21.66,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1237527837,
#      'estimated_diameter_max': 0.2767196367},
#     'meters': {'estimated_diameter_min': 123.7527836584,
#      'estimated_diameter_max': 276.719636665},
#     'miles': {'estimated_diameter_min': 0.0768963909,
#      'estimated_diameter_max': 0.1719455574},
#     'feet': {'estimated_diameter_min': 406.0130827378,
#      'estimated_diameter_max': 907.872852756}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-06',
#      'close_approach_date_full': '2024-Jan-06 16:52',
#      'epoch_date_close_approach': 1704559920000,
#      'relative_velocity': {'kilometers_per_second': '6.4568624469',
#       'kilometers_per_hour': '23244.7048088382',
#       'miles_per_hour': '14443.3556074695'},
#      'miss_distance': {'astronomical': '0.4595501104',
#       'lunar': '178.7649929456',
#       'kilometers': '68747717.674104848',
#       'miles': '42717850.9096209824'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-01-05': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3387092?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3387092',
#    'neo_reference_id': '3387092',
#    'name': '(2007 SG11)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3387092',
#    'absolute_magnitude_h': 22.68,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.077366861,
#      'estimated_diameter_max': 0.1729975604},
#     'meters': {'estimated_diameter_min': 77.3668609982,
#      'estimated_diameter_max': 172.9975603978},
#     'miles': {'estimated_diameter_min': 0.0480735238,
#      'estimated_diameter_max': 0.1074956671},
#     'feet': {'estimated_diameter_min': 253.8282922374,
#      'estimated_diameter_max': 567.5773160554}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-05',
#      'close_approach_date_full': '2024-Jan-05 21:10',
#      'epoch_date_close_approach': 1704489000000,
#      'relative_velocity': {'kilometers_per_second': '5.8695959378',
#       'kilometers_per_hour': '21130.5453762448',
#       'miles_per_hour': '13129.6991533672'},
#      'miss_distance': {'astronomical': '0.279217138',
#       'lunar': '108.615466682',
#       'kilometers': '41770289.11229606',
#       'miles': '25954854.111803228'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-01-08': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2168318?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2168318',
#    'neo_reference_id': '2168318',
#    'name': '168318 (1989 DA)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2168318',
#    'absolute_magnitude_h': 18.91,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.439091446,
#      'estimated_diameter_max': 0.9818383215},
#     'meters': {'estimated_diameter_min': 439.0914459693,
#      'estimated_diameter_max': 981.838321526},
#     'miles': {'estimated_diameter_min': 0.2728386909,
#      'estimated_diameter_max': 0.6100858597},
#     'feet': {'estimated_diameter_min': 1440.5887795938,
#      'estimated_diameter_max': 3221.2544387953}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-08',
#      'close_approach_date_full': '2024-Jan-08 04:17',
#      'epoch_date_close_approach': 1704687420000,
#      'relative_velocity': {'kilometers_per_second': '8.8851478203',
#       'kilometers_per_hour': '31986.5321530766',
#       'miles_per_hour': '19875.1871592269'},
#      'miss_distance': {'astronomical': '0.1176981136',
#       'lunar': '45.7845661904',
#       'kilometers': '17607387.097578032',
#       'miles': '10940723.0143675616'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3102728?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3102728',
#    'neo_reference_id': '3102728',
#    'name': '(2002 AY1)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3102728',
#    'absolute_magnitude_h': 20.85,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1797028549,
#      'estimated_diameter_max': 0.4018277992},
#     'meters': {'estimated_diameter_min': 179.7028548592,
#      'estimated_diameter_max': 401.8277992159},
#     'miles': {'estimated_diameter_min': 0.1116621426,
#      'estimated_diameter_max': 0.2496841414},
#     'feet': {'estimated_diameter_min': 589.5763143362,
#      'estimated_diameter_max': 1318.3327167796}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-08',
#      'close_approach_date_full': '2024-Jan-08 18:11',
#      'epoch_date_close_approach': 1704737460000,
#      'relative_velocity': {'kilometers_per_second': '17.3391696439',
#       'kilometers_per_hour': '62421.0107180472',
#       'miles_per_hour': '38785.9885764444'},
#      'miss_distance': {'astronomical': '0.0387907687',
#       'lunar': '15.0896090243',
#       'kilometers': '5803016.373182669',
#       'miles': '3605827.1698680722'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3599868?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3599868',
#    'neo_reference_id': '3599868',
#    'name': '(2012 DN31)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3599868',
#    'absolute_magnitude_h': 24.0,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0421264611,
#      'estimated_diameter_max': 0.0941976306},
#     'meters': {'estimated_diameter_min': 42.1264610556,
#      'estimated_diameter_max': 94.1976305719},
#     'miles': {'estimated_diameter_min': 0.0261761612,
#      'estimated_diameter_max': 0.0585316759},
#     'feet': {'estimated_diameter_min': 138.2101784897,
#      'estimated_diameter_max': 309.0473542854}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-08',
#      'close_approach_date_full': '2024-Jan-08 02:10',
#      'epoch_date_close_approach': 1704679800000,
#      'relative_velocity': {'kilometers_per_second': '20.2701167347',
#       'kilometers_per_hour': '72972.4202450971',
#       'miles_per_hour': '45342.2241239605'},
#      'miss_distance': {'astronomical': '0.438299464',
#       'lunar': '170.498491496',
#       'kilometers': '65568666.23654168',
#       'miles': '40742479.945487984'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}],
#  '2024-01-07': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2199003?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2199003',
#    'neo_reference_id': '2199003',
#    'name': '199003 (2005 WJ56)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2199003',
#    'absolute_magnitude_h': 18.16,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.620233153,
#      'estimated_diameter_max': 1.3868834919},
#     'meters': {'estimated_diameter_min': 620.2331529543,
#      'estimated_diameter_max': 1386.8834919048},
#     'miles': {'estimated_diameter_min': 0.3853948945,
#      'estimated_diameter_max': 0.8617691822},
#     'feet': {'estimated_diameter_min': 2034.8857375386,
#      'estimated_diameter_max': 4550.142835581}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-07',
#      'close_approach_date_full': '2024-Jan-07 02:32',
#      'epoch_date_close_approach': 1704594720000,
#      'relative_velocity': {'kilometers_per_second': '15.2908365812',
#       'kilometers_per_hour': '55047.0116924064',
#       'miles_per_hour': '34204.07234854'},
#      'miss_distance': {'astronomical': '0.1995345465',
#       'lunar': '77.6189385885',
#       'kilometers': '29849943.147815955',
#       'miles': '18547894.594751979'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2434188?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '2434188',
#    'neo_reference_id': '2434188',
#    'name': '434188 (2003 AD23)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2434188',
#    'absolute_magnitude_h': 19.09,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4041615334,
#      'estimated_diameter_max': 0.9037326626},
#     'meters': {'estimated_diameter_min': 404.1615334029,
#      'estimated_diameter_max': 903.7326625794},
#     'miles': {'estimated_diameter_min': 0.2511342562,
#      'estimated_diameter_max': 0.5615532683},
#     'feet': {'estimated_diameter_min': 1325.9893252496,
#      'estimated_diameter_max': 2965.0022686971}},
#    'is_potentially_hazardous_asteroid': True,
#    'close_approach_data': [{'close_approach_date': '2024-01-07',
#      'close_approach_date_full': '2024-Jan-07 07:28',
#      'epoch_date_close_approach': 1704612480000,
#      'relative_velocity': {'kilometers_per_second': '33.8373421713',
#       'kilometers_per_hour': '121814.4318166937',
#       'miles_per_hour': '75690.7507029895'},
#      'miss_distance': {'astronomical': '0.204313989',
#       'lunar': '79.478141721',
#       'kilometers': '30564937.56560343',
#       'miles': '18992171.524570134'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3398095?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3398095',
#    'neo_reference_id': '3398095',
#    'name': '(2007 YZ)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3398095',
#    'absolute_magnitude_h': 19.53,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3300311834,
#      'estimated_diameter_max': 0.7379721607},
#     'meters': {'estimated_diameter_min': 330.0311833581,
#      'estimated_diameter_max': 737.9721606833},
#     'miles': {'estimated_diameter_min': 0.2050718064,
#      'estimated_diameter_max': 0.4585544995},
#     'feet': {'estimated_diameter_min': 1082.7795076085,
#      'estimated_diameter_max': 2421.1685836563}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-07',
#      'close_approach_date_full': '2024-Jan-07 00:39',
#      'epoch_date_close_approach': 1704587940000,
#      'relative_velocity': {'kilometers_per_second': '17.5905759528',
#       'kilometers_per_hour': '63326.0734302496',
#       'miles_per_hour': '39348.3593489237'},
#      'miss_distance': {'astronomical': '0.1917667009',
#       'lunar': '74.5972466501',
#       'kilometers': '28687889.991567083',
#       'miles': '17825828.2461204254'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3520662?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3520662',
#    'neo_reference_id': '3520662',
#    'name': '(2010 JR34)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3520662',
#    'absolute_magnitude_h': 27.7,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0076657557,
#      'estimated_diameter_max': 0.0171411509},
#     'meters': {'estimated_diameter_min': 7.6657557353,
#      'estimated_diameter_max': 17.1411509231},
#     'miles': {'estimated_diameter_min': 0.0047632783,
#      'estimated_diameter_max': 0.0106510141},
#     'feet': {'estimated_diameter_min': 25.1501180466,
#      'estimated_diameter_max': 56.2373735944}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-07',
#      'close_approach_date_full': '2024-Jan-07 11:45',
#      'epoch_date_close_approach': 1704627900000,
#      'relative_velocity': {'kilometers_per_second': '10.5972841382',
#       'kilometers_per_hour': '38150.2228974764',
#       'miles_per_hour': '23705.0648887125'},
#      'miss_distance': {'astronomical': '0.203565311',
#       'lunar': '79.186905979',
#       'kilometers': '30452936.93148757',
#       'miles': '18922577.557645666'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False},
#   {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3596030?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#    'id': '3596030',
#    'neo_reference_id': '3596030',
#    'name': '(2012 BV13)',
#    'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3596030',
#    'absolute_magnitude_h': 22.29,
#    'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0925880583,
#      'estimated_diameter_max': 0.2070331923},
#     'meters': {'estimated_diameter_min': 92.5880583366,
#      'estimated_diameter_max': 207.0331923453},
#     'miles': {'estimated_diameter_min': 0.0575315344,
#      'estimated_diameter_max': 0.1286444218},
#     'feet': {'estimated_diameter_min': 303.766605313,
#      'estimated_diameter_max': 679.2427787741}},
#    'is_potentially_hazardous_asteroid': False,
#    'close_approach_data': [{'close_approach_date': '2024-01-07',
#      'close_approach_date_full': '2024-Jan-07 09:14',
#      'epoch_date_close_approach': 1704618840000,
#      'relative_velocity': {'kilometers_per_second': '18.7982461783',
#       'kilometers_per_hour': '67673.6862419358',
#       'miles_per_hour': '42049.7968762739'},
#      'miss_distance': {'astronomical': '0.476653263',
#       'lunar': '185.418119307',
#       'kilometers': '71306312.87334981',
#       'miles': '44307688.244694978'},
#      'orbiting_body': 'Earth'}],
#    'is_sentry_object': False}]}

# %%
data['near_earth_objects'].keys()
# Out:
# dict_keys(['2024-01-02', '2024-01-04', '2024-01-03', '2024-01-06', '2024-01-05', '2024-01-08', '2024-01-07'])

# %%
type(data['near_earth_objects'])
# Out:
# dict

# %%
data['near_earth_objects']['2024-01-03'] # list of dic
# Out:
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3154493?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '3154493',
#   'neo_reference_id': '3154493',
#   'name': '(2003 JV14)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3154493',
#   'absolute_magnitude_h': 21.39,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1401376972,
#     'estimated_diameter_max': 0.3133574171},
#    'meters': {'estimated_diameter_min': 140.1376971662,
#     'estimated_diameter_max': 313.3574170739},
#    'miles': {'estimated_diameter_min': 0.087077501,
#     'estimated_diameter_max': 0.1947112116},
#    'feet': {'estimated_diameter_min': 459.7693623707,
#     'estimated_diameter_max': 1028.0755482326}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 08:26',
#     'epoch_date_close_approach': 1704270360000,
#     'relative_velocity': {'kilometers_per_second': '13.6603242742',
#      'kilometers_per_hour': '49177.1673871585',
#      'miles_per_hour': '30556.7793689819'},
#     'miss_distance': {'astronomical': '0.2621610014',
#      'lunar': '101.9806295446',
#      'kilometers': '39218727.406507018',
#      'miles': '24369387.1869041284'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3440771?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '3440771',
#   'neo_reference_id': '3440771',
#   'name': '(2008 WZ94)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3440771',
#   'absolute_magnitude_h': 20.26,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.235806068,
#     'estimated_diameter_max': 0.5272783976},
#    'meters': {'estimated_diameter_min': 235.8060679997,
#     'estimated_diameter_max': 527.2783975542},
#    'miles': {'estimated_diameter_min': 0.1465230523,
#     'estimated_diameter_max': 0.3276355052},
#    'feet': {'estimated_diameter_min': 773.6419801361,
#     'estimated_diameter_max': 1729.9160578319}},
#   'is_potentially_hazardous_asteroid': True,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 08:50',
#     'epoch_date_close_approach': 1704271800000,
#     'relative_velocity': {'kilometers_per_second': '14.4225755627',
#      'kilometers_per_hour': '51921.2720256358',
#      'miles_per_hour': '32261.8592761513'},
#     'miss_distance': {'astronomical': '0.4821520704',
#      'lunar': '187.5571553856',
#      'kilometers': '72128922.747930048',
#      'miles': '44818834.3186007424'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3591759?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '3591759',
#   'neo_reference_id': '3591759',
#   'name': '(2011 YE40)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3591759',
#   'absolute_magnitude_h': 25.2,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#     'estimated_diameter_max': 0.0542050786},
#    'meters': {'estimated_diameter_min': 24.2412481101,
#     'estimated_diameter_max': 54.2050786336},
#    'miles': {'estimated_diameter_min': 0.0150628086,
#     'estimated_diameter_max': 0.0336814639},
#    'feet': {'estimated_diameter_min': 79.5316564495,
#     'estimated_diameter_max': 177.8381901842}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 23:21',
#     'epoch_date_close_approach': 1704324060000,
#     'relative_velocity': {'kilometers_per_second': '13.0832838643',
#      'kilometers_per_hour': '47099.8219113461',
#      'miles_per_hour': '29265.9976759695'},
#     'miss_distance': {'astronomical': '0.1185645923',
#      'lunar': '46.1216264047',
#      'kilometers': '17737010.465498401',
#      'miles': '11021267.2403078938'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595775?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '3595775',
#   'neo_reference_id': '3595775',
#   'name': '(2012 AB11)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3595775',
#   'absolute_magnitude_h': 22.32,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#     'estimated_diameter_max': 0.2041925905},
#    'meters': {'estimated_diameter_min': 91.3177025518,
#     'estimated_diameter_max': 204.1925904549},
#    'miles': {'estimated_diameter_min': 0.0567421722,
#     'estimated_diameter_max': 0.1268793541},
#    'feet': {'estimated_diameter_min': 299.59877124,
#     'estimated_diameter_max': 669.9232184681}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 09:58',
#     'epoch_date_close_approach': 1704275880000,
#     'relative_velocity': {'kilometers_per_second': '18.3613912555',
#      'kilometers_per_hour': '66101.0085197716',
#      'miles_per_hour': '41072.5960994103'},
#     'miss_distance': {'astronomical': '0.2870697327',
#      'lunar': '111.6701260203',
#      'kilometers': '42945020.553389349',
#      'miles': '26684798.3813330562'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3605578?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '3605578',
#   'neo_reference_id': '3605578',
#   'name': '(2012 LJ2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3605578',
#   'absolute_magnitude_h': 21.7,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1214940408,
#     'estimated_diameter_max': 0.2716689341},
#    'meters': {'estimated_diameter_min': 121.4940407996,
#     'estimated_diameter_max': 271.6689340891},
#    'miles': {'estimated_diameter_min': 0.0754928736,
#     'estimated_diameter_max': 0.1688071972},
#    'feet': {'estimated_diameter_min': 398.6025088171,
#     'estimated_diameter_max': 891.3023057169}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 13:43',
#     'epoch_date_close_approach': 1704289380000,
#     'relative_velocity': {'kilometers_per_second': '17.3904977402',
#      'kilometers_per_hour': '62605.7918647103',
#      'miles_per_hour': '38900.8043950473'},
#     'miss_distance': {'astronomical': '0.4856779711',
#      'lunar': '188.9287307579',
#      'kilometers': '72656389.982481557',
#      'miles': '45146587.2600452066'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3751529?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '3751529',
#   'neo_reference_id': '3751529',
#   'name': '(2016 GZ215)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3751529',
#   'absolute_magnitude_h': 21.08,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1616422833,
#     'estimated_diameter_max': 0.3614431336},
#    'meters': {'estimated_diameter_min': 161.6422833399,
#     'estimated_diameter_max': 361.4431335863},
#    'miles': {'estimated_diameter_min': 0.1004398272,
#     'estimated_diameter_max': 0.2245902814},
#    'feet': {'estimated_diameter_min': 530.3224688728,
#     'estimated_diameter_max': 1185.8370903951}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 14:28',
#     'epoch_date_close_approach': 1704292080000,
#     'relative_velocity': {'kilometers_per_second': '3.7257304746',
#      'kilometers_per_hour': '13412.6297084999',
#      'miles_per_hour': '8334.0864985954'},
#     'miss_distance': {'astronomical': '0.3169592421',
#      'lunar': '123.2971451769',
#      'kilometers': '47416427.494974327',
#      'miles': '29463201.8185546326'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2668499?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '2668499',
#   'neo_reference_id': '2668499',
#   'name': '668499 (2012 AB11)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2668499',
#   'absolute_magnitude_h': 22.32,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0913177026,
#     'estimated_diameter_max': 0.2041925905},
#    'meters': {'estimated_diameter_min': 91.3177025518,
#     'estimated_diameter_max': 204.1925904549},
#    'miles': {'estimated_diameter_min': 0.0567421722,
#     'estimated_diameter_max': 0.1268793541},
#    'feet': {'estimated_diameter_min': 299.59877124,
#     'estimated_diameter_max': 669.9232184681}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 09:58',
#     'epoch_date_close_approach': 1704275880000,
#     'relative_velocity': {'kilometers_per_second': '18.3613912419',
#      'kilometers_per_hour': '66101.008470871',
#      'miles_per_hour': '41072.5960690253'},
#     'miss_distance': {'astronomical': '0.2870697328',
#      'lunar': '111.6701260592',
#      'kilometers': '42945020.568349136',
#      'miles': '26684798.3906286368'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False},
#  {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2676480?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#   'id': '2676480',
#   'neo_reference_id': '2676480',
#   'name': '676480 (2016 GZ215)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2676480',
#   'absolute_magnitude_h': 21.08,
#   'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1616422833,
#     'estimated_diameter_max': 0.3614431336},
#    'meters': {'estimated_diameter_min': 161.6422833399,
#     'estimated_diameter_max': 361.4431335863},
#    'miles': {'estimated_diameter_min': 0.1004398272,
#     'estimated_diameter_max': 0.2245902814},
#    'feet': {'estimated_diameter_min': 530.3224688728,
#     'estimated_diameter_max': 1185.8370903951}},
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_data': [{'close_approach_date': '2024-01-03',
#     'close_approach_date_full': '2024-Jan-03 14:28',
#     'epoch_date_close_approach': 1704292080000,
#     'relative_velocity': {'kilometers_per_second': '3.725730427',
#      'kilometers_per_hour': '13412.6295371653',
#      'miles_per_hour': '8334.0863921347'},
#     'miss_distance': {'astronomical': '0.316959242',
#      'lunar': '123.297145138',
#      'kilometers': '47416427.48001454',
#      'miles': '29463201.809259052'},
#     'orbiting_body': 'Earth'}],
#   'is_sentry_object': False}]

# %%
data['near_earth_objects']['2024-01-02'][0]
# Out:
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#  'id': '2415949',
#  'neo_reference_id': '2415949',
#  'name': '415949 (2001 XY10)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#  'absolute_magnitude_h': 19.37,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
#    'estimated_diameter_max': 0.7944013596},
#   'meters': {'estimated_diameter_min': 355.267088298,
#    'estimated_diameter_max': 794.4013596028},
#   'miles': {'estimated_diameter_min': 0.2207526659,
#    'estimated_diameter_max': 0.4936179672},
#   'feet': {'estimated_diameter_min': 1165.5744739718,
#    'estimated_diameter_max': 2606.3037566394}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '2024-01-02',
#    'close_approach_date_full': '2024-Jan-02 13:14',
#    'epoch_date_close_approach': 1704201240000,
#    'relative_velocity': {'kilometers_per_second': '15.8905264223',
#     'kilometers_per_hour': '57205.8951204341',
#     'miles_per_hour': '35545.5185541386'},
#    'miss_distance': {'astronomical': '0.3372535274',
#     'lunar': '131.1916221586',
#     'kilometers': '50452409.349026638',
#     'miles': '31349673.4658100844'},
#    'orbiting_body': 'Earth'}],
#  'is_sentry_object': False}

# %%
data['near_earth_objects']['2024-01-02'][1]
# Out:
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3160747?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#  'id': '3160747',
#  'neo_reference_id': '3160747',
#  'name': '(2003 SR84)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3160747',
#  'absolute_magnitude_h': 26.0,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#    'estimated_diameter_max': 0.0375007522},
#   'meters': {'estimated_diameter_min': 16.7708462163,
#    'estimated_diameter_max': 37.5007521798},
#   'miles': {'estimated_diameter_min': 0.0104209175,
#    'estimated_diameter_max': 0.0233018799},
#   'feet': {'estimated_diameter_min': 55.0224631002,
#    'estimated_diameter_max': 123.0339677816}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '2024-01-02',
#    'close_approach_date_full': '2024-Jan-02 22:45',
#    'epoch_date_close_approach': 1704235500000,
#    'relative_velocity': {'kilometers_per_second': '10.7191818981',
#     'kilometers_per_hour': '38589.054833182',
#     'miles_per_hour': '23977.7379878735'},
#    'miss_distance': {'astronomical': '0.1323425924',
#     'lunar': '51.4812684436',
#     'kilometers': '19798169.933318188',
#     'miles': '12302012.3446714744'},
#    'orbiting_body': 'Earth'}],
#  'is_sentry_object': False}

# %%
data['near_earth_objects']['2024-01-02'][0]['id']
# Out:
# '2415949'

# %%
data['near_earth_objects']['2024-01-03'][1]['name']
# Out:
# '(2008 WZ94)'

# %%
data['near_earth_objects']['2024-01-02'][0]['name']
# Out:
# '415949 (2001 XY10)'

# %%
data['near_earth_objects']['2024-01-02'][0]['absolute_magnitude_h']
# Out:
# 19.37

# %%
data['near_earth_objects']['2024-01-02'][0]['estimated_diameter']['kilometers']['estimated_diameter_min']
# Out:
# 0.3552670883

# %%
data['near_earth_objects']['2024-01-02'][0]['estimated_diameter']['kilometers']['estimated_diameter_max']
# Out:
# 0.7944013596

# %%
data['near_earth_objects']['2024-01-02'][0]['is_potentially_hazardous_asteroid']
# Out:
# False

# %%
data['near_earth_objects']['2024-01-02'][0]['neo_reference_id']
# Out:
# '2415949'

# %%
data['near_earth_objects']['2024-01-02'][0]['close_approach_data'][0]['close_approach_date']
# Out:
# '2024-01-02'

# %%
data['near_earth_objects']['2024-01-02'][0]['close_approach_data'][0]['relative_velocity']['kilometers_per_hour']
# Out:
# '57205.8951204341'

# %%
data['near_earth_objects']['2024-01-02'][0]['close_approach_data'][0]['miss_distance']['astronomical']
# Out:
# '0.3372535274'

# %%
data['near_earth_objects']['2024-01-02'][0]['close_approach_data'][0]['miss_distance']['kilometers']
# Out:
# '50452409.349026638'

# %%
data['near_earth_objects']['2024-01-02'][0]['close_approach_data'][0]['miss_distance']['lunar']
# Out:
# '131.1916221586'

# %%
data['near_earth_objects']['2024-01-02'][0]['close_approach_data'][0]['orbiting_body']
# Out:
# 'Earth'

# %%
import pandas as pd
import requests
from datetime import datetime
asteroids_data = []
target = 10000
API_KEY = "q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K"
url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-07&api_key={API_KEY}"

#response = requests.get(url)
#data = response.json()
#details = data['near_earth_objects']

while len(asteroids_data) < target:
    
    response = requests.get(url)
    data = response.json()
    details = data['near_earth_objects']
    
    for date, ast_details in details.items():
        for ast in ast_details:
             #for approach in  ast['close_approach_data']:
                 asteroids_data.append(dict(
                            id = int(ast['id']),
                            name = ast['name'],
                            absolute_magnitude_h = float(ast['absolute_magnitude_h']),
                            estimated_diameter_min_km = float(ast['estimated_diameter']['kilometers']['estimated_diameter_min']),
                            estimated_diameter_max_km = float(ast['estimated_diameter']['kilometers']['estimated_diameter_max']),
                            is_potentially_hazardous_asteroid  = ast['is_potentially_hazardous_asteroid'],
                            neo_reference_id = int(ast['neo_reference_id']),
                            close_approach_date = datetime.strptime(ast['close_approach_data'][0]['close_approach_date'],'%Y-%m-%d').date(),
                            relative_velocity_kmph = float(ast['close_approach_data'][0]['relative_velocity']['kilometers_per_hour']),
                            astronomical = float(ast['close_approach_data'][0]['miss_distance']['astronomical']),
                            miss_distance_km = float(ast['close_approach_data'][0]['miss_distance']['kilometers']),
                            miss_distance_lunar = float(ast['close_approach_data'][0]['miss_distance']['lunar']),
                            orbiting_body = ast['close_approach_data'][0]['orbiting_body']))
                                                
                         

                 if len(asteroids_data) >= target:
                        break
        if len(asteroids_data) >= target:
                        break
    url = data['links'].get('next')

#df = pd.DataFrame(asteroids_data)

        
#df['close_approach_date'] = pd.to_datetime(df['close_approach_date'], errors='coerce')

#df['close_approach_date'] = df['close_approach_date'].dt.date
#print(df['close_approach_date'].values)

# %%
df.head(40)

# %%
asteroids_data['close_approach_date'].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 asteroids_data['close_approach_date'].unique()
#
# TypeError: list indices must be integers or slices, not str

# %%
import pprint 


pprint.pprint(data)
# Out:
# {'element_count': 58,
#  'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2028-07-08&end_date=2028-07-14&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K',
#            'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2028-06-26&end_date=2028-07-02&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K',
#            'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2028-07-02&end_date=2028-07-08&detailed=false&api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#  'near_earth_objects': {'2028-07-02': [{'absolute_magnitude_h': 18.92,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '05:10',
#                                                                  'epoch_date_close_approach': 1846127400000,
#                                                                  'miss_distance': {'astronomical': '0.3529856046',
#                                                                                    'kilometers': '52805894.588822202',
#                                                                                    'lunar': '137.3114001894',
#                                                                                    'miles': '32812061.3819903076'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '47100.7158234563',
#                                                                                        'kilometers_per_second': '13.0835321732',
#                                                                                        'miles_per_hour': '29266.5531181915'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 3206.4541190445,
#                                                                         'estimated_diameter_min': 1433.9698753835},
#                                                                'kilometers': {'estimated_diameter_max': 0.9773271842,
#                                                                               'estimated_diameter_min': 0.437074004},
#                                                                'meters': {'estimated_diameter_max': 977.3271842103,
#                                                                           'estimated_diameter_min': 437.0740040305},
#                                                                'miles': {'estimated_diameter_max': 0.6072827698,
#                                                                          'estimated_diameter_min': 0.271585111}},
#                                         'id': '2154652',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2154652?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '154652 (2004 EP20)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2154652',
#                                         'neo_reference_id': '2154652'},
#                                        {'absolute_magnitude_h': 20.45,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '23:01',
#                                                                  'epoch_date_close_approach': 1846191660000,
#                                                                  'miss_distance': {'astronomical': '0.136189778',
#                                                                                    'kilometers': '20373700.70457286',
#                                                                                    'lunar': '52.977823642',
#                                                                                    'miles': '12659630.582951068'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '27643.1633203366',
#                                                                                        'kilometers_per_second': '7.6786564779',
#                                                                                        'miles_per_hour': '17176.3866753502'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1584.9845383766,
#                                                                         'estimated_diameter_min': 708.8266342193},
#                                                                'kilometers': {'estimated_diameter_max': 0.4831032718,
#                                                                               'estimated_diameter_min': 0.2160503512},
#                                                                'meters': {'estimated_diameter_max': 483.1032718379,
#                                                                           'estimated_diameter_min': 216.0503511964},
#                                                                'miles': {'estimated_diameter_max': 0.3001863631,
#                                                                          'estimated_diameter_min': 0.1342474228}},
#                                         'id': '2388945',
#                                         'is_potentially_hazardous_asteroid': True,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2388945?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '388945 (2008 TZ3)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2388945',
#                                         'neo_reference_id': '2388945'},
#                                        {'absolute_magnitude_h': 20.21,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '17:43',
#                                                                  'epoch_date_close_approach': 1846172580000,
#                                                                  'miss_distance': {'astronomical': '0.4378059335',
#                                                                                    'kilometers': '65494835.124961645',
#                                                                                    'lunar': '170.3065081315',
#                                                                                    'miles': '40696603.420074901'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '47016.3253459608',
#                                                                                        'kilometers_per_second': '13.0600903739',
#                                                                                        'miles_per_hour': '29214.1161573277'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1770.2109792133,
#                                                                         'estimated_diameter_min': 791.6624168075},
#                                                                'kilometers': {'estimated_diameter_max': 0.5395602892,
#                                                                               'estimated_diameter_min': 0.2412986969},
#                                                                'meters': {'estimated_diameter_max': 539.5602891983,
#                                                                           'estimated_diameter_min': 241.2986969214},
#                                                                'miles': {'estimated_diameter_max': 0.3352671165,
#                                                                          'estimated_diameter_min': 0.1499360126}},
#                                         'id': '2446924',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2446924?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '446924 (2002 VV17)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2446924',
#                                         'neo_reference_id': '2446924'},
#                                        {'absolute_magnitude_h': 29.1,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '18:06',
#                                                                  'epoch_date_close_approach': 1846173960000,
#                                                                  'miss_distance': {'astronomical': '0.3357053672',
#                                                                                    'kilometers': '50220807.880687864',
#                                                                                    'lunar': '130.5893878408',
#                                                                                    'miles': '31205762.9866019632'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '34703.1829933043',
#                                                                                        'kilometers_per_second': '9.6397730537',
#                                                                                        'miles_per_hour': '21563.2083438118'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 29.5137932072,
#                                                                         'estimated_diameter_min': 13.198969577},
#                                                                'kilometers': {'estimated_diameter_max': 0.0089958039,
#                                                                               'estimated_diameter_min': 0.0040230458},
#                                                                'meters': {'estimated_diameter_max': 8.9958038817,
#                                                                           'estimated_diameter_min': 4.0230457983},
#                                                                'miles': {'estimated_diameter_max': 0.0055897317,
#                                                                          'estimated_diameter_min': 0.002499804}},
#                                         'id': '3160748',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3160748?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2003 SW130)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3160748',
#                                         'neo_reference_id': '3160748'},
#                                        {'absolute_magnitude_h': 27.1,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '06:15',
#                                                                  'epoch_date_close_approach': 1846131300000,
#                                                                  'miss_distance': {'astronomical': '0.4689289045',
#                                                                                    'kilometers': '70150765.294633415',
#                                                                                    'lunar': '182.4133438505',
#                                                                                    'miles': '43589664.274494527'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '87099.0799676033',
#                                                                                        'kilometers_per_second': '24.1941888799',
#                                                                                        'miles_per_hour': '54119.9811054255'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 74.1352966996,
#                                                                         'estimated_diameter_min': 33.1543125905},
#                                                                'kilometers': {'estimated_diameter_max': 0.0225964377,
#                                                                               'estimated_diameter_min': 0.0101054342},
#                                                                'meters': {'estimated_diameter_max': 22.5964377109,
#                                                                           'estimated_diameter_min': 10.1054341542},
#                                                                'miles': {'estimated_diameter_max': 0.0140407711,
#                                                                          'estimated_diameter_min': 0.0062792237}},
#                                         'id': '3545558',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3545558?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2010 RX30)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3545558',
#                                         'neo_reference_id': '3545558'},
#                                        {'absolute_magnitude_h': 22.28,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '03:21',
#                                                                  'epoch_date_close_approach': 1846120860000,
#                                                                  'miss_distance': {'astronomical': '0.4370291897',
#                                                                                    'kilometers': '65378635.906945939',
#                                                                                    'lunar': '170.0043547933',
#                                                                                    'miles': '40624400.5740903982'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '67554.3773255951',
#                                                                                        'kilometers_per_second': '18.7651048127',
#                                                                                        'miles_per_hour': '41975.662955451'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 682.3780209891,
#                                                                         'estimated_diameter_min': 305.1687282567},
#                                                                'kilometers': {'estimated_diameter_max': 0.2079888141,
#                                                                               'estimated_diameter_min': 0.0930154254},
#                                                                'meters': {'estimated_diameter_max': 207.9888141418,
#                                                                           'estimated_diameter_min': 93.0154253961},
#                                                                'miles': {'estimated_diameter_max': 0.1292382174,
#                                                                          'estimated_diameter_min': 0.0577970879}},
#                                         'id': '3736406',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3736406?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2015 XN169)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3736406',
#                                         'neo_reference_id': '3736406'},
#                                        {'absolute_magnitude_h': 23.0,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '21:01',
#                                                                  'epoch_date_close_approach': 1846184460000,
#                                                                  'miss_distance': {'astronomical': '0.0401348062',
#                                                                                    'kilometers': '6004081.520382794',
#                                                                                    'lunar': '15.6124396118',
#                                                                                    'miles': '3730763.2589747972'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '24205.2192694581',
#                                                                                        'kilometers_per_second': '6.7236720193',
#                                                                                        'miles_per_hour': '15040.1819399585'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 489.807047955,
#                                                                         'estimated_diameter_min': 219.0483710172},
#                                                                'kilometers': {'estimated_diameter_max': 0.1492931834,
#                                                                               'estimated_diameter_min': 0.0667659413},
#                                                                'meters': {'estimated_diameter_max': 149.2931834393,
#                                                                           'estimated_diameter_min': 66.7659413495},
#                                                                'miles': {'estimated_diameter_max': 0.0927664547,
#                                                                          'estimated_diameter_min': 0.0414864197}},
#                                         'id': '3771629',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771629?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2017 FR2)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3771629',
#                                         'neo_reference_id': '3771629'},
#                                        {'absolute_magnitude_h': 25.0,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '22:50',
#                                                                  'epoch_date_close_approach': 1846191000000,
#                                                                  'miss_distance': {'astronomical': '0.4829329695',
#                                                                                    'kilometers': '72245743.589974965',
#                                                                                    'lunar': '187.8609251355',
#                                                                                    'miles': '44891423.423845917'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '71518.5546007363',
#                                                                                        'kilometers_per_second': '19.8662651669',
#                                                                                        'miles_per_hour': '44438.8485517742'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 194.9956979785,
#                                                                         'estimated_diameter_min': 87.2047272},
#                                                                'kilometers': {'estimated_diameter_max': 0.0594346868,
#                                                                               'estimated_diameter_min': 0.02658},
#                                                                'meters': {'estimated_diameter_max': 59.4346868419,
#                                                                           'estimated_diameter_min': 26.58},
#                                                                'miles': {'estimated_diameter_max': 0.0369309908,
#                                                                          'estimated_diameter_min': 0.0165160412}},
#                                         'id': '3799273',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3799273?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2018 CB2)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3799273',
#                                         'neo_reference_id': '3799273'},
#                                        {'absolute_magnitude_h': 25.51,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '18:08',
#                                                                  'epoch_date_close_approach': 1846174080000,
#                                                                  'miss_distance': {'astronomical': '0.1815403496',
#                                                                                    'kilometers': '27158049.619215352',
#                                                                                    'lunar': '70.6191959944',
#                                                                                    'miles': '16875229.5185897776'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '38455.1609068177',
#                                                                                        'kilometers_per_second': '10.6819891408',
#                                                                                        'miles_per_hour': '23894.5415090168'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 154.1789309435,
#                                                                         'estimated_diameter_min': 68.9509140576},
#                                                                'kilometers': {'estimated_diameter_max': 0.0469937366,
#                                                                               'estimated_diameter_min': 0.0210162379},
#                                                                'meters': {'estimated_diameter_max': 46.9937366478,
#                                                                           'estimated_diameter_min': 21.0162379322},
#                                                                'miles': {'estimated_diameter_max': 0.0292005451,
#                                                                          'estimated_diameter_min': 0.0130588808}},
#                                         'id': '3825159',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3825159?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2018 LS3)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3825159',
#                                         'neo_reference_id': '3825159'},
#                                        {'absolute_magnitude_h': 25.8,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '19:40',
#                                                                  'epoch_date_close_approach': 1846179600000,
#                                                                  'miss_distance': {'astronomical': '0.0187960344',
#                                                                                    'kilometers': '2811846.710686728',
#                                                                                    'lunar': '7.3116573816',
#                                                                                    'miles': '1747200.5272557264'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '31612.6093074324',
#                                                                                        'kilometers_per_second': '8.7812803632',
#                                                                                        'miles_per_hour': '19642.8460443876'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 134.9040630575,
#                                                                         'estimated_diameter_min': 60.3309310875},
#                                                                'kilometers': {'estimated_diameter_max': 0.0411187571,
#                                                                               'estimated_diameter_min': 0.0183888672},
#                                                                'meters': {'estimated_diameter_max': 41.1187571041,
#                                                                           'estimated_diameter_min': 18.388867207},
#                                                                'miles': {'estimated_diameter_max': 0.0255500032,
#                                                                          'estimated_diameter_min': 0.0114263088}},
#                                         'id': '54017652',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54017652?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2020 MK3)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54017652',
#                                         'neo_reference_id': '54017652'},
#                                        {'absolute_magnitude_h': 24.59,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '12:59',
#                                                                  'epoch_date_close_approach': 1846155540000,
#                                                                  'miss_distance': {'astronomical': '0.485327365',
#                                                                                    'kilometers': '72603940.05671255',
#                                                                                    'lunar': '188.792344985',
#                                                                                    'miles': '45113996.38743119'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '93856.6455745943',
#                                                                                        'kilometers_per_second': '26.0712904374',
#                                                                                        'miles_per_hour': '58318.8695793917'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 235.5185018048,
#                                                                         'estimated_diameter_min': 105.3270759989},
#                                                                'kilometers': {'estimated_diameter_max': 0.0717860371,
#                                                                               'estimated_diameter_min': 0.0321036917},
#                                                                'meters': {'estimated_diameter_max': 71.7860370529,
#                                                                           'estimated_diameter_min': 32.1036917371},
#                                                                'miles': {'estimated_diameter_max': 0.0446057616,
#                                                                          'estimated_diameter_min': 0.019948303}},
#                                         'id': '54104254',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54104254?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2021 AN)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54104254',
#                                         'neo_reference_id': '54104254'},
#                                        {'absolute_magnitude_h': 23.36,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '05:10',
#                                                                  'epoch_date_close_approach': 1846127400000,
#                                                                  'miss_distance': {'astronomical': '0.4229603666',
#                                                                                    'kilometers': '63273969.937779142',
#                                                                                    'lunar': '164.5315826074',
#                                                                                    'miles': '39316621.7833584796'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '77663.2829055692',
#                                                                                        'kilometers_per_second': '21.5731341404',
#                                                                                        'miles_per_hour': '48256.9437587411'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 414.9779586668,
#                                                                         'estimated_diameter_min': 185.5837849486},
#                                                                'kilometers': {'estimated_diameter_max': 0.1264852778,
#                                                                               'estimated_diameter_min': 0.0565659358},
#                                                                'meters': {'estimated_diameter_max': 126.4852777541,
#                                                                           'estimated_diameter_min': 56.5659358422},
#                                                                'miles': {'estimated_diameter_max': 0.0785942835,
#                                                                          'estimated_diameter_min': 0.0351484321}},
#                                         'id': '54169953',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54169953?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2021 NC6)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54169953',
#                                         'neo_reference_id': '54169953'},
#                                        {'absolute_magnitude_h': 26.72,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '10:37',
#                                                                  'epoch_date_close_approach': 1846147020000,
#                                                                  'miss_distance': {'astronomical': '0.1537018696',
#                                                                                    'kilometers': '22993472.307177752',
#                                                                                    'lunar': '59.7900272744',
#                                                                                    'miles': '14287481.1723748976'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '45183.7385341492',
#                                                                                        'kilometers_per_second': '12.5510384817',
#                                                                                        'miles_per_hour': '28075.4179797328'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 88.3130797061,
#                                                                         'estimated_diameter_min': 39.494809905},
#                                                                'kilometers': {'estimated_diameter_max': 0.0269178258,
#                                                                               'estimated_diameter_min': 0.0120380177},
#                                                                'meters': {'estimated_diameter_max': 26.917825833,
#                                                                           'estimated_diameter_min': 12.0380176738},
#                                                                'miles': {'estimated_diameter_max': 0.0167259564,
#                                                                          'estimated_diameter_min': 0.0074800751}},
#                                         'id': '54224433',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': True,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54224433?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2021 WN2)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54224433',
#                                         'neo_reference_id': '54224433',
#                                         'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/54224433?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                        {'absolute_magnitude_h': 23.68,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-02',
#                                                                  'close_approach_date_full': '2028-Jul-02 '
#                                                                                              '08:45',
#                                                                  'epoch_date_close_approach': 1846140300000,
#                                                                  'miss_distance': {'astronomical': '0.3250875205',
#                                                                                    'kilometers': '48632400.630381335',
#                                                                                    'lunar': '126.4590454745',
#                                                                                    'miles': '30218772.488619023'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '28933.2602703182',
#                                                                                        'kilometers_per_second': '8.0370167418',
#                                                                                        'miles_per_hour': '17978.0027496319'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 358.1170761255,
#                                                                         'estimated_diameter_min': 160.154825224},
#                                                                'kilometers': {'estimated_diameter_max': 0.1091540813,
#                                                                               'estimated_diameter_min': 0.0488151892},
#                                                                'meters': {'estimated_diameter_max': 109.1540813101,
#                                                                           'estimated_diameter_min': 48.8151891662},
#                                                                'miles': {'estimated_diameter_max': 0.0678251807,
#                                                                          'estimated_diameter_min': 0.0303323429}},
#                                         'id': '54418496',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418496?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2023 YV1)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418496',
#                                         'neo_reference_id': '54418496'}],
#                         '2028-07-03': [{'absolute_magnitude_h': 19.35,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-03',
#                                                                  'close_approach_date_full': '2028-Jul-03 '
#                                                                                              '22:15',
#                                                                  'epoch_date_close_approach': 1846275300000,
#                                                                  'miss_distance': {'astronomical': '0.0956131727',
#                                                                                    'kilometers': '14303526.979862149',
#                                                                                    'lunar': '37.1935241803',
#                                                                                    'miles': '8887799.5325456962'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '58288.1831992634',
#                                                                                        'kilometers_per_second': '16.1911619998',
#                                                                                        'miles_per_hour': '36218.0102773423'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 2630.4195883808,
#                                                                         'estimated_diameter_min': 1176.3594017933},
#                                                                'kilometers': {'estimated_diameter_max': 0.8017518649,
#                                                                               'estimated_diameter_min': 0.3585543342},
#                                                                'meters': {'estimated_diameter_max': 801.7518648824,
#                                                                           'estimated_diameter_min': 358.5543341929},
#                                                                'miles': {'estimated_diameter_max': 0.498185358,
#                                                                          'estimated_diameter_min': 0.2227952652}},
#                                         'id': '2523808',
#                                         'is_potentially_hazardous_asteroid': True,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2523808?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '523808 (2007 ML24)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2523808',
#                                         'neo_reference_id': '2523808'},
#                                        {'absolute_magnitude_h': 19.21,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-03',
#                                                                  'close_approach_date_full': '2028-Jul-03 '
#                                                                                              '17:25',
#                                                                  'epoch_date_close_approach': 1846257900000,
#                                                                  'miss_distance': {'astronomical': '0.307840139',
#                                                                                    'kilometers': '46052229.09490393',
#                                                                                    'lunar': '119.749814071',
#                                                                                    'miles': '28615528.239897034'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '72308.0837321269',
#                                                                                        'kilometers_per_second': '20.0855788145',
#                                                                                        'miles_per_hour': '44929.4312501096'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 2805.5953301751,
#                                                                         'estimated_diameter_min': 1254.7003751255},
#                                                                'kilometers': {'estimated_diameter_max': 0.8551454293,
#                                                                               'estimated_diameter_min': 0.3824326621},
#                                                                'meters': {'estimated_diameter_max': 855.1454292727,
#                                                                           'estimated_diameter_min': 382.4326621004},
#                                                                'miles': {'estimated_diameter_max': 0.5313625705,
#                                                                          'estimated_diameter_min': 0.2376325657}},
#                                         'id': '3463398',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
# ...
#                                                                           'estimated_diameter_min': 33.4622374455},
#                                                                'miles': {'estimated_diameter_max': 0.0464933628,
#                                                                          'estimated_diameter_min': 0.0207924639}},
#                                         'id': '3516408',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3516408?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2010 GK65)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3516408',
#                                         'neo_reference_id': '3516408'},
#                                        {'absolute_magnitude_h': 21.66,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-08',
#                                                                  'close_approach_date_full': '2028-Jul-08 '
#                                                                                              '17:46',
#                                                                  'epoch_date_close_approach': 1846691160000,
#                                                                  'miss_distance': {'astronomical': '0.3471239564',
#                                                                                    'kilometers': '51929004.503412868',
#                                                                                    'lunar': '135.0312190396',
#                                                                                    'miles': '32267187.1490708584'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '91041.9391305562',
#                                                                                        'kilometers_per_second': '25.2894275363',
#                                                                                        'miles_per_hour': '56569.9204558725'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 907.872852756,
#                                                                         'estimated_diameter_min': 406.0130827378},
#                                                                'kilometers': {'estimated_diameter_max': 0.2767196367,
#                                                                               'estimated_diameter_min': 0.1237527837},
#                                                                'meters': {'estimated_diameter_max': 276.719636665,
#                                                                           'estimated_diameter_min': 123.7527836584},
#                                                                'miles': {'estimated_diameter_max': 0.1719455574,
#                                                                          'estimated_diameter_min': 0.0768963909}},
#                                         'id': '3684344',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3684344?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2014 QK362)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3684344',
#                                         'neo_reference_id': '3684344'},
#                                        {'absolute_magnitude_h': 20.6,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-08',
#                                                                  'close_approach_date_full': '2028-Jul-08 '
#                                                                                              '10:06',
#                                                                  'epoch_date_close_approach': 1846663560000,
#                                                                  'miss_distance': {'astronomical': '0.4886735368',
#                                                                                    'kilometers': '73104520.230646616',
#                                                                                    'lunar': '190.0940058152',
#                                                                                    'miles': '45425042.4841146608'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '57099.4263343678',
#                                                                                        'kilometers_per_second': '15.8609517595',
#                                                                                        'miles_per_hour': '35479.3629909298'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1479.1936371367,
#                                                                         'estimated_diameter_min': 661.5155049046},
#                                                                'kilometers': {'estimated_diameter_max': 0.4508582062,
#                                                                               'estimated_diameter_min': 0.2016299194},
#                                                                'meters': {'estimated_diameter_max': 450.8582061718,
#                                                                           'estimated_diameter_min': 201.6299194428},
#                                                                'miles': {'estimated_diameter_max': 0.2801502144,
#                                                                          'estimated_diameter_min': 0.1252869847}},
#                                         'id': '3776112',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3776112?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2017 MD7)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3776112',
#                                         'neo_reference_id': '3776112'},
#                                        {'absolute_magnitude_h': 25.35,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-08',
#                                                                  'close_approach_date_full': '2028-Jul-08 '
#                                                                                              '14:44',
#                                                                  'epoch_date_close_approach': 1846680240000,
#                                                                  'miss_distance': {'astronomical': '0.2430475261',
#                                                                                    'kilometers': '36359392.213329407',
#                                                                                    'lunar': '94.5454876529',
#                                                                                    'miles': '22592678.6849315366'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '18793.1050886172',
#                                                                                        'kilometers_per_second': '5.2203069691',
#                                                                                        'miles_per_hour': '11677.3046590911'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 165.9682558353,
#                                                                         'estimated_diameter_min': 74.223260431},
#                                                                'kilometers': {'estimated_diameter_max': 0.0505871228,
#                                                                               'estimated_diameter_min': 0.0226232491},
#                                                                'meters': {'estimated_diameter_max': 50.5871227598,
#                                                                           'estimated_diameter_min': 22.6232490554},
#                                                                'miles': {'estimated_diameter_max': 0.0314333711,
#                                                                          'estimated_diameter_min': 0.0140574309}},
#                                         'id': '3801935',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': True,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3801935?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2018 EL4)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3801935',
#                                         'neo_reference_id': '3801935',
#                                         'sentry_data': 'http://api.nasa.gov/neo/rest/v1/neo/sentry/3801935?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                        {'absolute_magnitude_h': 23.7,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-08',
#                                                                  'close_approach_date_full': '2028-Jul-08 '
#                                                                                              '08:58',
#                                                                  'epoch_date_close_approach': 1846659480000,
#                                                                  'miss_distance': {'astronomical': '0.0525467101',
#                                                                                    'kilometers': '7860875.906467487',
#                                                                                    'lunar': '20.4406702289',
#                                                                                    'miles': '4884521.7899938406'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '61768.1067342325',
#                                                                                        'kilometers_per_second': '17.1578074262',
#                                                                                        'miles_per_hour': '38380.2994316124'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 354.8338390368,
#                                                                         'estimated_diameter_min': 158.6865169607},
#                                                                'kilometers': {'estimated_diameter_max': 0.1081533507,
#                                                                               'estimated_diameter_min': 0.0483676488},
#                                                                'meters': {'estimated_diameter_max': 108.1533506775,
#                                                                           'estimated_diameter_min': 48.3676488219},
#                                                                'miles': {'estimated_diameter_max': 0.0672033557,
#                                                                          'estimated_diameter_min': 0.0300542543}},
#                                         'id': '3843276',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3843276?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2019 NW5)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843276',
#                                         'neo_reference_id': '3843276'},
#                                        {'absolute_magnitude_h': 27.0,
#                                         'close_approach_data': [{'close_approach_date': '2028-07-08',
#                                                                  'close_approach_date_full': '2028-Jul-08 '
#                                                                                              '12:50',
#                                                                  'epoch_date_close_approach': 1846673400000,
#                                                                  'miss_distance': {'astronomical': '0.2668011032',
#                                                                                    'kilometers': '39912876.752370184',
#                                                                                    'lunar': '103.7856291448',
#                                                                                    'miles': '24800711.5896451792'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '59631.3240755558',
#                                                                                        'kilometers_per_second': '16.5642566877',
#                                                                                        'miles_per_hour': '37052.5857846141'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 77.6291855923,
#                                                                         'estimated_diameter_min': 34.7168272045},
#                                                                'kilometers': {'estimated_diameter_max': 0.023661375,
#                                                                               'estimated_diameter_min': 0.0105816886},
#                                                                'meters': {'estimated_diameter_max': 23.6613750114,
#                                                                           'estimated_diameter_min': 10.5816885933},
#                                                                'miles': {'estimated_diameter_max': 0.0147024923,
#                                                                          'estimated_diameter_min': 0.0065751544}},
#                                         'id': '54244182',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54244182?api_key=q000AArBbylThy5ojAIrBu0cJyp1UA9JuHAcO98K'},
#                                         'name': '(2022 BW6)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54244182',
#                                         'neo_reference_id': '54244182'}]}}

# %%
print(response)
# Out:
# <Response [200]>

# %%
asteroids_data[1]['close_approach_date']
# Out:
# datetime.date(2024, 1, 2)

# %%
len(asteroids_data)
# Out:
# 10000

# %%
asteroids_data[0].
# Out:
# {'id': 2415949,
#  'name': '415949 (2001 XY10)',
#  'absolute_magnitude_h': 19.37,
#  'estimated_diameter_min_km': 0.3552670883,
#  'estimated_diameter_max_km': 0.7944013596,
#  'is_potentially_hazardous_asteroid': False,
#  'neo_reference_id': 2415949,
#  'close_approach_date': datetime.date(2024, 1, 2),
#  'relative_velocity_kmph': 57205.8951204341,
#  'astronomical': 0.3372535274,
#  'miss_distance_km': 50452409.349026635,
#  'miss_distance_lunar': 131.1916221586,
#  'orbiting_body': 'Earth'}

# %%
asteroids_data[2]
# Out:
# {'id': 3309828,
#  'name': '(2005 YQ96)',
#  'absolute_magnitude_h': 20.62,
#  'estimated_diameter_min_km': 0.1997813652,
#  'estimated_diameter_max_km': 0.4467247133,
#  'is_potentially_hazardous_asteroid': True,
#  'neo_reference_id': 3309828,
#  'close_approach_date': datetime.date(2024, 1, 2),
#  'relative_velocity_kmph': 56413.0143519451,
#  'astronomical': 0.1670126223,
#  'miss_distance_km': 24984732.5591945,
#  'miss_distance_lunar': 64.9679100747,
#  'orbiting_body': 'Earth'}

# %%
asteroids_data[3]
# Out:
# {'id': 3457842,
#  'name': '(2009 HC21)',
#  'absolute_magnitude_h': 22.1,
#  'estimated_diameter_min_km': 0.1010543415,
#  'estimated_diameter_max_km': 0.2259643771,
#  'is_potentially_hazardous_asteroid': False,
#  'neo_reference_id': 3457842,
#  'close_approach_date': datetime.date(2024, 1, 2),
#  'relative_velocity_kmph': 21891.1182185894,
#  'astronomical': 0.4920511029,
#  'miss_distance_km': 73609796.92499082,
#  'miss_distance_lunar': 191.4078790281,
#  'orbiting_body': 'Earth'}

# %%
# sql creating database and table

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\hp\anaconda3\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import pymysql

# %%
myconnection = pymysql.connect(host = '127.0.0.1',user='root', password='Thiru@1994')

# %%
cur = myconnection.cursor()

# %%
cur.execute("create database NASA_PROJECT")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cur.execute("create database NASA_PROJECT")
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'nasa_project'; database exists")

# %%
myconnection = pymysql.connect(host = '127.0.0.1',user='root', password='Thiru@1994', database = 'NASA_PROJECT')

# %%
cur = myconnection.cursor()

# %%
cur.execute("create table asteroids(id INTEGER,name TEXT,absolute_magnitude_h FLOAT,estimated_diameter_min_km FLOAT,estimated_diameter_max_km FLOAT,is_potentially_hazardous_asteroid BOOLEAN)")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cur.execute("create table asteroids(id INTEGER,name TEXT,absolute_magnitude_h FLOAT,estimated_diameter_min_km FLOAT,estimated_diameter_max_km FLOAT,is_potentially_hazardous_asteroid BOOLEAN)")
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'asteroids' already exists")

# %%
myconnection.commit()

# %%
myconnection_2 = pymysql.connect(host = '127.0.0.1',user='root', password='Thiru@1994', database = 'NASA_PROJECT')

# %%
cur = myconnection_2.cursor()

# %%
cur.execute("create table close_approach (neo_reference_id INTEGER, close_approach_date DATE, relative_velocity_kmph FLOAT, astronomical FLOAT, miss_distance_km FLOAT,miss_distance_lunar FLOAT, orbiting_body TEXT)")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cur.execute("create table close_approach (neo_reference_id INTEGER, close_approach_date DATE, relative_velocity_kmph FLOAT, astronomical FLOAT, miss_distance_km FLOAT,miss_distance_lunar FLOAT, orbiting_body TEXT)")
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'close_approach' already exists")

# %%
myconnection_2.commit()

# %%
myconnection = pymysql.connect(host = '127.0.0.1',user='root', password='Thiru@1994', database = 'NASA_PROJECT')

# %%
cur = myconnection.cursor()

# %%
insert_query = """insert into asteroids (id,name,absolute_magnitude_h,estimated_diameter_min_km,estimated_diameter_max_km,is_potentially_hazardous_asteroid)values(%s,%s,%s,%s,%s,%s)"""
for ast in asteroids_data:
    values = (ast['id'],
              ast['name'],
              ast['absolute_magnitude_h'],
              ast['estimated_diameter_min_km'],
              ast['estimated_diameter_max_km'],
              ast['is_potentially_hazardous_asteroid'])
    cur.execute(insert_query,values)
myconnection.commit()

# %%
myconnection = pymysql.connect(host = '127.0.0.1',user='root', password='Thiru@1994', database = 'NASA_PROJECT')

# %%
cur = myconnection.cursor()

# %%
asteroids_data[0]
# Out:
# {'id': 2415949,
#  'name': '415949 (2001 XY10)',
#  'absolute_magnitude_h': 19.37,
#  'estimated_diameter_min_km': 0.3552670883,
#  'estimated_diameter_max_km': 0.7944013596,
#  'is_potentially_hazardous_asteroid': False,
#  'neo_reference_id': 2415949,
#  'close_approach_date': datetime.date(2024, 1, 2),
#  'relative_velocity_kmph': 57205.8951204341,
#  'astronomical': 0.3372535274,
#  'miss_distance_km': 50452409.349026635,
#  'miss_distance_lunar': 131.1916221586,
#  'orbiting_body': 'Earth'}

# %%
insert_query_1 = """insert into close_approach (neo_reference_id,close_approach_date,relative_velocity_kmph,astronomical,miss_distance_km,miss_distance_lunar,orbiting_body)values(%s,%s,%s,%s,%s,%s,%s)"""
for ast in asteroids_data:
    values = (ast['neo_reference_id'],
              ast['close_approach_date'],
              ast['relative_velocity_kmph'],
              ast['astronomical'] ,
              ast['miss_distance_km'],
              ast['miss_distance_lunar'],
              ast['orbiting_body'])
    cur.execute(insert_query_1,values)
myconnection.commit()
